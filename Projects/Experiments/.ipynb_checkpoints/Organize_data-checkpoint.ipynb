# %%
import os 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
import pandas as pd 
import scipy.stats
# %matplotlib inline
# %run clean.py

# %run methods.ipynb
###Collect the  data of the sessions to plot
sns.set_style("darkgrid")



#############
study_sessions = ["7_6_2021","24_6_2021","16_6_2021","17_6_2021","23_6_2021","21_6_2021","22_6_2021"]
#############
#study_sessions = ["17_6_2021","23_6_2021","21_6_2021","22_6_2021"]
#for N = 20
#study_sessions = ["7_6_2021","24_6_2021","16_6_2021"]
#for N = 10
join_name = 'basura'
 
#############

dataframes_saved = [0 for i in range(len(study_sessions))]
#os.chdir(start_point)
start_point = os.getcwd()
#os.mkdir(os.path.join(start_point,join_name))
for i,session in enumerate(study_sessions):
    os.chdir(os.path.join(start_point,session))
    df_1 = pd.read_excel('ethnic_markers_acabado.xlsx')
    df_2 = pd.read_excel('norm_compliance_acabado.xlsx')
    participants = pd.read_excel('participants.xlsx')
    rounds_1 = int(max(df_1['subsession.round_number'].unique()))
    rounds_2 = int(max(df_2['subsession.round_number'].unique()))
    num_participants = int(max(df_1['participant.id_in_session'].unique()))
    ### Then, clean the data, separately 
    players_info = dar_xeito(df_1,df_2,participants,rounds_1,rounds_2,num_participants)
    crear_txt(players_info,session)
    players_info = update_players_info(players_info,df_1,participants)
    ###Then accumulate the data 
    dataframes_saved[i] = players_info
###Then, make the appropiate plots
###For that, create directory

#Stack the auxiliary session
init_session = dataframes_saved[0]
aux_part = [init_session[i] for i in range(len(init_session)) if init_session[i][0]['id_in_subsession'] == 2]
for elem in aux_part:
    elem[0]["id_in_subsession"] = 6
    dataframes_saved[1].append(elem)
dataframes_saved.remove(init_session)
study_sessions.remove(study_sessions[0])
dataframes_saved[1] = dataframes_saved[1][:-3]
dataframes_saved[2] = dataframes_saved[2][:-4]
es = ["N=10; e=1","N=10; e=0.5","N=20; e=1","N=20; e=1","N=20; e=0.5","N=20; e=0.5"]
# Out:
# Inactives:
# Dropout:
# ID Number                                                   71182648V
# ID Type                                                           dni
# First name                                                     Sandra
# Last name                                              Muñoz San José
# Email Address                               100386901@alumnos.uc3m.es
# Paypal_database                               sandramunoz97@gmail.com
# Player                                                              1
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                       1
# id_in_subsession                                                    1
# Name: 0, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   04230140A
# ID Type                                                           dni
# First name                                                      Marta
# Last name                                               Valle Sánchez
# Email Address                                 marta.valle99@gmail.com
# Paypal_database                               marta.valle99@gmail.com
# Player                                                             10
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      10
# id_in_subsession                                                    1
# Name: 9, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   28983883L
# ID Type                                                           dni
# First name                                                    Alberto
# Last name                                             Jimenez Bonillo
# Email Address                                 albertojb2002@gmail.com
# Paypal_database                               albertojb2002@gmail.com
# Player                                                             11
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      11
# id_in_subsession                                                    2
# Name: 10, dtype: object
# ***********
# 10
# ***********
# ID Number                                                   51002396B
# ID Type                                                           dni
# First name                                                      Laura
# Last name                                            Serrano Folguera
# Email Address                               100386869@alumnos.uc3m.es
# Paypal_database                        lauraserranofolguera@gmail.com
# Player                                                             21
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      21
# id_in_subsession                                                    3
# Name: 20, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   73028278N
# ID Type                                                           dni
# First name                                                    Gonzalo
# Last name                                            Novel San Andrés
# Email Address                                gonzalonovel90@gmail.com
# Paypal_database                              gonzalonovel90@gmail.com
# Player                                                             27
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      27
# id_in_subsession                                                    3
# Name: 26, dtype: object
# ***********
# 76
# ***********
# ID Number                                                   42568047W
# ID Type                                                           dni
# First name                                                    Manuela
# Last name                                                      Martin
# Email Address                            manuelmartin9912@outlook.com
# Paypal_database                                                   NaN
# Player                                                             30
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      30
# id_in_subsession                                                    3
# Name: 29, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   50256475A
# ID Type                                                           dni
# First name                                                      Mario
# Last name                                                      Maroto
# Email Address                               100429025@alumnos.uc3m.es
# Paypal_database                            mario.maroto.141@gmail.com
# Player                                                             32
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      32
# id_in_subsession                                                    4
# Name: 31, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   53939755V
# ID Type                                                           dni
# First name                                                    Adriana
# Last name                                                  Gila Zarco
# Email Address                               100408672@alumnos.uc3m.es
# Paypal_database                               adrianagz2000@gmail.com
# Player                                                             35
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      35
# id_in_subsession                                                    4
# Name: 34, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   53901042J
# ID Type                                                           dni
# First name                                                      Sonia
# Last name                                               Alonso Carlos
# Email Address                               sonia.alonso423@gmail.com
# Paypal_database                             sonia.alonso423@gmail.com
# Player                                                             46
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      46
# id_in_subsession                                                    5
# Name: 45, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   26520056k
# ID Type                                                           dni
# First name                                                       Blas
# Last name                                               Moreno Laguna
# Email Address                               100406683@alumnos.uc3m.es
# Paypal_database                                   slab10000@gmail.com
# Player                                                             47
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      47
# id_in_subsession                                                    5
# Name: 46, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   03147367r
# ID Type                                                           dni
# First name                                                     CAMINO
# Last name                                            MONSALVE CARCAÑO
# Email Address                                minomonsalve@hotmail.com
# Paypal_database                                                   NaN
# Player                                                             54
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      54
# id_in_subsession                                                    6
# Name: 53, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   34290978W
# ID Type                                                           dni
# First name                                                      María
# Last name                                              Lancho Lavilla
# Email Address                               100383005@alumnos.uc3m.es
# Paypal_database                        maria.lancho.lavilla@gmail.com
# Player                                                             65
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      65
# id_in_subsession                                                    7
# Name: 64, dtype: object
# ***********
# 44
# ***********
# ID Number                                                   53959632E
# ID Type                                                           dni
# First name                                                  Sebastián
# Last name                                                       López
# Email Address                                      sebas96@hotmail.es
# Paypal_database                                 sebas19ls96@gmail.com
# Player                                                             68
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      68
# id_in_subsession                                                    7
# Name: 67, dtype: object
# ***********
# 83
# ***********
# Inactives:
# ID Number                                                  51231389Q
# ID type                                                          dni
# First name                                                     Delia
# Last name                                            Sánchez Delgado
# Email address                                  delisd2000@hotmail.es
# Paypal_database                                delisd2000@hotmail.es
# Player                                                             3
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 2, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  75164228k
# ID type                                                          dni
# First name                                                     Berta
# Last name                                             Rodriguez Lara
# Email address                                  bertyrini@hotmail.com
# Paypal_database                                bertyrini@hotmail.com
# Player                                                            24
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 23, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  47034352l
# ID type                                                          dni
# First name                                                     Laura
# Last name                                           Rodríguez Andrés
# Email address                          Laurarodriguez.foto@gmail.com
# Paypal_database                        laurarodriguez.foto@gmail.com
# Player                                                            31
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 30, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  Y2620433B
# ID type                                                          nie
# First name                                                   Lennard
# Last name                                                   Palomino
# Email address                            servicioswebccs@outlook.com
# Paypal_database                               lennardwilde@yahoo.com
# Player                                                            54
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 53, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  87654223G
# ID type                                                          dni
# First name                                                     Sofía
# Last name                                                    Álvarez
# Email address                           altiericorreasofia@gmail.com
# Paypal_database                            100428711@alumnos.uc3m.es
# Player                                                            58
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 57, dtype: object
# ***********
# 87
# ***********
# Dropout:
# ID Number                                                   05714616J
# ID type                                                           dni
# First name                                                    Alberto
# Last name                                            Malagon Gonzalez
# Email address                               100364043@alumnos.uc3m.es
# Paypal_database                                 kamisetiyas@gmail.com
# Player                                                             20
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      20
# id_in_subsession                                                    2
# Name: 19, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   51145540A
# ID type                                                           dni
# First name                                                     Blanca
# Last name                                             Moraleda Montes
# Email address                                        bmm709@gmail.com
# Paypal_database                                      bmm709@gmail.com
# Player                                                             55
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      55
# id_in_subsession                                                    6
# Name: 54, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   88150866P
# ID type                                                           dni
# First name                                                     Rafael
# Last name                                                       Pérez
# Email address                                rafitaperezita@gmail.com
# Paypal_database                              rafitaperezita@gmail.com
# Player                                                             56
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      56
# id_in_subsession                                                    6
# Name: 55, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   42070469L
# ID type                                                           dni
# First name                                                   Severino
# Last name                                                Ramos Alonso
# Email address                         macarenagomezgarcia79@gmail.com
# Paypal_database                       macarenagomezgarcia79@gmail.com
# Player                                                             57
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      57
# id_in_subsession                                                    6
# Name: 56, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   02711816R
# ID type                                                           dni
# First name                                                     Miguel
# Last name                                          Monedero Maldonado
# Email address                               100315410@alumnos.uc3m.es
# Paypal_database                                   3monedero@gmail.com
# Player                                                             59
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      59
# id_in_subsession                                                    6
# Name: 58, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   27432707D
# ID type                                                           dni
# First name                                                      Alejo
# Last name                                              Martinez Soria
# Email address                              alejomartinez89@outlook.es
# Paypal_database                                                   NaN
# Player                                                             60
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      60
# id_in_subsession                                                    6
# Name: 59, dtype: object
# ***********
# 87
# ***********
# Inactives:
# ID Number                                                  50482517R
# First name                                                     Jaime
# Last name                                                García Moya
# Email Address                              100430772@alumnos.uc3m.es
# Paypal_database                         garciamoyadanielgm@gmail.com
# Player                                                             5
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 4, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  47463772Y
# First name                                                Luis Ángel
# Last name                                              Lobete Biachó
# Email Address                             luislobetebiacho@gmail.com
# Paypal_database                           Luislobetebiacho@gmail.com
# Player                                                            30
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 29, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  47471279S
# First name                                                    Alvaro
# Last name                                             Flores Soriano
# Email Address                              100451221@alumnos.uc3m.es
# Paypal_database                               alvaroflosor@gmail.com
# Player                                                            36
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 35, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  17879524Z
# First name                                                     María
# Last name                                                     García
# Email Address                                  merygarci01@gmail.com
# Paypal_database                                merygarci01@gmail.com
# Player                                                            55
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 54, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  49590207E
# First name                                                    Eliana
# Last name                                            Gutierrez Muñoz
# Email Address                                    eligumu04@gmail.com
# Paypal_database                                eligumu04@hotmail.com
# Player                                                            57
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 56, dtype: object
# ***********
# 83
# ***********
# Dropout:
# ID Number                                                   72536109C
# First name                                                      Nerea
# Last name                                                   Zabalegui
# Email Address                               100431317@alumnos.uc3m.es
# Paypal_database                               zabaleginerea@gmail.com
# Player                                                             66
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      66
# id_in_subsession                                                    7
# Name: 65, dtype: object
# ***********
# 66
# ***********
# ID Number                                                    12267213
# First name                                                    Yurimia
# Last name                                           Ramirez Dominguez
# Email Address                                      yuberado@gmail.com
# Paypal_database                                    yuberado@gmail.com
# Player                                                             70
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      70
# id_in_subsession                                                    7
# Name: 69, dtype: object
# ***********
# 83
# ***********
# Inactives:
# ID Number                                                  02318472A
# ID type                                                          dni
# First name                                              Juan Vicente
# Last name                                                      PÉREZ
# Email Address                                   juanvipeva@gmail.com
# Paypal_database                                 juanvipeva@gmail.com
# Player                                                             7
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 5, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  50578327Q
# ID type                                                          dni
# First name                                                     Elena
# Last name                                             Valkov Lorenzo
# Email Address                                 elenavalor18@gmail.com
# Paypal_database                               elenavalor18@gmail.com
# Player                                                            26
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 24, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  02303688P
# ID type                                                          dni
# First name                                                    Adrian
# Last name                                          Zapatero Matesanz
# Email Address                     adrian.zapatero.matesanz@gmail.com
# Paypal_database                   adrian.zapatero.matesanz@gmail.com
# Player                                                            33
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 30, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  73100603W
# ID type                                                          dni
# First name                                                      Lian
# Last name                                              Martínez Moya
# Email Address                                 lianmartnz98@gmail.com
# Paypal_database                               lianmartnz98@gmail.com
# Player                                                            39
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 33, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  70876014L
# ID type                                                          dni
# First name                                                      Vega
# Last name                                               Miguel Ruano
# Email Address                                        vegg@hotmail.es
# Paypal_database                                      vegg@hotmail.es
# Player                                                            41
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 35, dtype: object
# ***********
# 83
# ***********
# ID Number                                                  51146232M
# ID type                                                          dni
# First name                                                    Carlos
# Last name                                             Moreno Casares
# Email Address                              100364440@alumnos.uc3m.es
# Paypal_database                                    cargeto@gmail.com
# Player                                                            47
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 40, dtype: object
# ***********
# 83
# ***********
# Dropout:
# Inactives:
# ID Number                                                  08843859z
# ID type                                                          dni
# First name                                                      JOSE
# Last name                                       HERNANDEZ SAN MILLAN
# Email address                                    josehsm@hotmail.com
# Paypal_database                                  josehsm@hotmail.com
# Player                                                             3
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 2, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  71947316G
# ID type                                                          dni
# First name                                                    Manuel
# Last name                                          Escudero Escudero
# Email address                               manuelescu87@outlook.com
# Paypal_database                             manuelescu87@outlook.com
# Player                                                            35
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 34, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  X9636019P
# ID type                                                          nie
# First name                                                   Mohamed
# Last name                                                      Chafi
# Email address                                  mohachafi98@gmail.com
# Paypal_database                              chafimohamed5@gmail.com
# Player                                                            37
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 36, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   95991746
# ID type                                                          dni
# First name                                                    Nelson
# Last name                                                  Maldonado
# Email address                                     nemj5691@gmail.com
# Paypal_database                                   nemj5691@gmail.com
# Player                                                            46
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 45, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  54406246E
# ID type                                                          dni
# First name                                                     Pablo
# Last name                                              Aísa Serranos
# Email address                                     pablo3as@gmail.com
# Paypal_database                                   pablo3as@gmail.com
# Player                                                            47
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 46, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  52761200M
# ID type                                                          dni
# First name                                          María Concepción
# Last name                                              Lozano Melero
# Email address                                   conchalome@gmail.com
# Paypal_database                                 conchalome@gmail.com
# Player                                                            68
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 67, dtype: object
# ***********
# 87
# ***********
# Dropout:
# ID Number                                                   48793522B
# ID type                                                           dni
# First name                                                      Josué
# Last name                                               Pérez Sabater
# Email address                                     josu.ps13@gmail.com
# Paypal_database                                   josu.ps13@gmail.com
# Player                                                             42
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      42
# id_in_subsession                                                    2
# Name: 41, dtype: object
# ***********
# 83
# ***********
# ID Number                                                   50480711N
# ID type                                                           dni
# First name                                                     Andrea
# Last name                                                 Parés López
# Email address                                   andreazxt@hotmail.com
# Paypal_database                                 andreazxt@hotmail.com
# Player                                                             66
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      66
# id_in_subsession                                                    4
# Name: 65, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   51133892Q
# ID type                                                           dni
# First name                                                      Laura
# Last name                                                 Casado Mayo
# Email address                               100428672@alumnos.uc3m.es
# Paypal_database                             lauracasadomayo@gmail.com
# Player                                                             67
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      67
# id_in_subsession                                                    4
# Name: 66, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   X8834238F
# ID type                                                           nie
# First name                                              Elena-Mihaela
# Last name                                                       Cozma
# Email address                               100408652@alumnos.uc3m.es
# Paypal_database                                  elenamc000@gmail.com
# Player                                                             69
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                       amarillo
# Comments                                                           -1
# id_in_session                                                      69
# id_in_subsession                                                    4
# Name: 68, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   47310177M
# ID type                                                           dni
# First name                                                    BEATRIZ
# Last name                                              MOHEDANO MUÑOZ
# Email address                              beatrizmohedano9@gmail.com
# Paypal_database                            beatrizmohedano9@gmail.com
# Player                                                             70
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      70
# id_in_subsession                                                    4
# Name: 69, dtype: object
# ***********
# 87
# ***********
# Inactives:
# ID Number                                                  06021085F
# ID Type                                                          dni
# First Name                                                      Luis
# Last name                                             Beamud Garrido
# Email Address                            luisbeamudgarrido@gmail.com
# Paypal_database                          luisbeamudgarrido@gmail.com
# Player                                                             7
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 4, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  05468729L
# ID Type                                                          dni
# First Name                                                     Elena
# Last name                                              Menéndez Marí
# Email Address                                 elenita22846@gmail.com
# Paypal_database                               elenita22846@gmail.com
# Player                                                             8
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 5, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  39391460G
# ID Type                                                          dni
# First Name                                                 ALEJANDRO
# Last name                                                     MENDEZ
# Email Address                          alejandromendez2299@gmail.com
# Paypal_database                        alejandromendez2299@gmail.com
# Player                                                            17
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 13, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  51526315J
# ID Type                                                          dni
# First Name                                               Marta María
# Last name                                              Sánchez Penim
# Email Address                                martuchi.m.10@gmail.com
# Paypal_database                              martuchi.m.10@gmail.com
# Player                                                            27
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 21, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  54994177G
# ID Type                                                          dni
# First Name                                                Lucas Luis
# Last name                                        Ribeiro de Oliveira
# Email Address                             lucas.brasil5799@gmail.com
# Paypal_database                              lucas.rib5799@gmail.com
# Player                                                            28
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 22, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  54110089J
# ID Type                                                          dni
# First Name                                                   Carlota
# Last name                                                    Morales
# Email Address                              carlotamoralesp@gmail.com
# Paypal_database                            carlotamoralesp@gmail.com
# Player                                                            36
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 29, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  05280537j
# ID Type                                                          dni
# First Name                                               JUAN CARLOS
# Last name                                             martin serrano
# Email Address                                    tremulo@hotmail.com
# Paypal_database                                  tremulo@hotmail.com
# Player                                                            72
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 61, dtype: object
# ***********
# 87
# ***********
# ID Number                                                  53959514L
# ID Type                                                          dni
# First Name                                              Jose Enrique
# Last name                                            Rosa Cabanillas
# Email Address                            josercabanillas10@gmail.com
# Paypal_database                          josercabanillas10@gmail.com
# Player                                                            77
# Link               https://cambridge.ibsen-h2020.eu/InitializePar...
# Name: 66, dtype: object
# ***********
# 87
# ***********
# Dropout:
# ID Number                                                   06271952J
# ID Type                                                           dni
# First Name                                                      Laura
# Last name                                                Librero Mora
# Email Address                                lauralaura5465@gmail.com
# Paypal_database                              lauralaura5465@gmail.com
# Player                                                             79
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      79
# id_in_subsession                                                    4
# Name: 68, dtype: object
# ***********
# 87
# ***********
# ID Number                                                   88965104T
# ID Type                                                           dni
# First Name                                                       Hugo
# Last name                                                Lopez Torres
# Email Address                               hugitoslopezito@gmail.com
# Paypal_database                             hugitoslopezito@gmail.com
# Player                                                             80
# Link                https://cambridge.ibsen-h2020.eu/InitializePar...
# Paypal                                                             -1
# Bias                                                              0.0
# Bias_payoff                                                       0.0
# Marker                                                           azul
# Comments                                                           -1
# id_in_session                                                      80
# id_in_subsession                                                    4
# Name: 69, dtype: object
# ***********
# 87
# ***********
# Inactives:
# ID number                                                    77498972N
# ID type                                                            dni
# First name                                                       Celia
# Last name                                              García Valverde
# Email address                                     dinita2001@gmail.com
# Paypal_database                                   dinita2001@gmail.com
# Player                                                               1
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 0, dtype: object
# ***********
# 87
# ***********
# ID number                                                    54131241M
# ID type                                                            dni
# First name                                                       Paula
# Last name                                                Carrasco Díaz
# Email address                                100364548@alumnos.uc3m.es
# Paypal_database                            paulacarrascoes98@gmail.com
# Player                                                              18
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 17, dtype: object
# ***********
# 87
# ***********
# ID number                                                    50558274L
# ID type                                                            dni
# First name                                                     Gabriel
# Last name                                              Franco Ferrería
# Email address                                      gabriff02@gmail.com
# Paypal_database                                    gabriff02@gmail.com
# Player                                                              27
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 26, dtype: object
# ***********
# 87
# ***********
# ID number                                                     45348562
# ID type                                                            dni
# First name                                                      Raquel
# Last name                                             Cardeñosa Romera
# Email address                               raquel.cardenosa@gmail.com
# Paypal_database                             raquel.cardenosa@gmail.com
# Player                                                              29
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 28, dtype: object
# ***********
# 87
# ***********
# ID number                                                     49593954
# ID type                                                            dni
# First name                                               ANGEL GONZALO
# Last name                                          LOPEZ SANCHEZ-ROJAS
# Email address                             alopezsanchezrojas@gmail.com
# Paypal_database                          angelgonzalo.lopito@gmail.com
# Player                                                              36
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 35, dtype: object
# ***********
# 87
# ***********
# ID number                                                    29791237G
# ID type                                                            dni
# First name                                                  José Ramón
# Last name                                              Hernández López
# Email address                                    jrhernandez@gmail.com
# Paypal_database                                       jrhl@vodafone.es
# Player                                                              59
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Name: 58, dtype: object
# ***********
# 87
# ***********
# Dropout:
# ID number                                                     7524295Y
# ID type                                                            dni
# First name                                                     Ricardo
# Last name                                                       Concha
# Email address                                 laura.concha96@gmail.com
# Paypal_database                                   richyc3623@gmail.com
# Player                                                               5
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                        5
# id_in_subsession                                                     1
# Name: 4, dtype: object
# ***********
# 12
# ***********
# ID number                                                    03960099M
# ID type                                                            dni
# First name                                                     Cecilia
# Last name                                              Aviles Martinez
# Email address                                      avilsceci@gmail.com
# Paypal_database                                    avilsceci@gmail.com
# Player                                                               9
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                        9
# id_in_subsession                                                     1
# Name: 8, dtype: object
# ***********
# 6
# ***********
# ID number                                                    73101363A
# ID type                                                            dni
# First name                                                 Maria Salud
# Last name                                                Montrull Resa
# Email address                                  mmontrullresa@gmail.com
# Paypal_database                                mmontrullresa@gmail.com
# Player                                                              28
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                        amarillo
# Comments                                                            -1
# id_in_session                                                       28
# id_in_subsession                                                     2
# Name: 27, dtype: object
# ***********
# 81
# ***********
# ID number                                                    48816482V
# ID type                                                            dni
# First name                                                   Christian
# Last name                                               Bajo Fernandez
# Email address                               christian18189@hotmail.com
# Paypal_database                             christian18189@hotmail.com
# Player                                                              48
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                       48
# id_in_subsession                                                     3
# Name: 47, dtype: object
# ***********
# 5
# ***********
# ID number                                                    05995636L
# ID type                                                            dni
# First name                                                       Laura
# Last name                                                      Borrego
# Email address                                      laurabmnr@gmail.com
# Paypal_database                                    laurabmnr@gmail.com
# Player                                                              67
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                       67
# id_in_subsession                                                     4
# Name: 66, dtype: object
# ***********
# 87
# ***********
# ID number                                                    54362306N
# ID type                                                            dni
# First name                                                       Paula
# Last name                                             Abollado Urrutia
# Email address                                100395033@alumnos.uc3m.es
# Paypal_database                                    paulaauhk@gmail.com
# Player                                                              68
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                       68
# id_in_subsession                                                     4
# Name: 67, dtype: object
# ***********
# 87
# ***********
# ID number                                                    50171647E
# ID type                                                            dni
# First name                                                       María
# Last name                                                       García
# Email address                                  sergiuticonde@gmail.com
# Paypal_database                                sergiuticonde@gmail.com
# Player                                                              69
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                       69
# id_in_subsession                                                     4
# Name: 68, dtype: object
# ***********
# 87
# ***********
# ID number                                                    71952234T
# ID type                                                            dni
# First name                                                      Adrian
# Last name                                                Laso Gonzalez
# Email address                                   adrianlaso13@gmail.com
# Paypal_database                                 adrianlaso13@gmail.com
# Player                                                              70
# Link                 https://cambridge.ibsen-h2020.eu/InitializePar...
# Mail merge status                          MAIL SENT 22-Jun-21 4:50 PM
# Paypal                                                              -1
# Bias                                                               0.0
# Bias_payoff                                                        0.0
# Marker                                                            azul
# Comments                                                            -1
# id_in_session                                                       70
# id_in_subsession                                                     4
# Name: 69, dtype: object
# ***********
# 87
# ***********

# %%
###
#dataframes_saved,study_sessions = include_new_groups(dataframes_saved,study_sessions)
include_semaforo(dataframes_saved)
include_aspiration(dataframes_saved)
###

# %% [markdown]
# ## Figure 1

# %%
def subplots_probability(dataframes_saved,round_ini,round_end,title=""):
    ijaux=0
    fig,ax =plt.subplots(8,3,sharex=True,sharey=True,figsize=(10,20))
    fig.supxlabel("Coordination rate  with same marker",fontsize=20)
    fig.supylabel("Coordination rate with different marker",fontsize = 20)
    cmap = colors.ListedColormap(['orange', 'blue'])
    for ij,players_info in enumerate(dataframes_saved):
            group_2 = 0
            if (ij>2) & (np.mod(ij,2)!= 0 ): group_2 = 3
            for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
                players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
                suc = []
                sampenl = []
                av_mark = []
                std_mark = []
                av_mark_2 = []
                std_mark_2 = []
                grupo = []
                grupo_2 = []

                for j in range(len(players_info_group)):
                    lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["marker_partner"].iloc[i]==players_info_group[j][0]["Marker"]]
                    lista_prueba_2 = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["marker_partner"].iloc[i]!=players_info_group[j][0]["Marker"]]
                    lista_dic = {"amarillo":0,"azul":1}
                    #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                    #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                    suc.append(players_info[j][1]["success"].iloc[-1])
                    av_mark.append(lista_prueba.count(1.0)/len(lista_prueba))
                    av_mark_2.append(lista_prueba_2.count(1.0)/len(lista_prueba_2))
                    grupo.append(players_info[j][0]["Marker"])
                    grupo_2.append(players_info[j][1]["success"].iloc[round_end])

                
                groupaux=0
                if group==4:
                    ijaux +=1
                if group>3:
                    groupaux= -3
                ax[ij+ijaux,group+groupaux-1].set_title("Group: "+str(group+group_2), fontsize=16)
                if (group+group_2)== 1 :
                        ax[ij+ijaux,group+groupaux-1].set_ylabel(es[ij],fontsize=15)
   
                plt.xlim((-0.1,1.1))
                plt.ylim((-0.1,1.1))
                for color in lista_dic.keys():
                    temp_x = list(filter(lambda x:grupo[x] == color,range(len(av_mark))))
                    plot_x = [av_mark[x] for x in temp_x]
                    plot_y = [av_mark_2[x] for x in temp_x]
                    ax[ij+ijaux,group+groupaux-1].scatter(plot_x,plot_y,label=color,c=cmap.colors[lista_dic[color]],cmap=cmap)
        #fig.savefig("subplots_success,"+str(round_end)+".jpg")
    return

# %%
subplots_probability(dataframes_saved,round_ini = 0 ,round_end =40)

# %% [markdown]
# ## Figure 2

# %%
#Obtain dataframes separated for zealots and non zealots

def obtain_zealots_dataframe(dataframes_saved,threshold):
    list_zealots = []
    dataframes_saved_non_zealots = [0]*len(dataframes_saved)
    dataframes_saved_zealots = [0]*len(dataframes_saved)
    for ij,players_info in enumerate(dataframes_saved):
        zealots = []

        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                moda_agente = player[1]["acción"].mode()[0] 
                zealot = len(player[1]["acción"][player[1]["acción"] == moda_agente])
                if zealot>threshold:
                    player[0]["Zealot"] = "Yes"
                else:
                    player[0]["Zealot"] = "No"
        players_info_non_zealots = list(filter(lambda x:x[0]["Zealot"] == "No",players_info))
        players_info_zealots = list(filter(lambda x:x[0]["Zealot"] == "Yes",players_info))
        dataframes_saved_non_zealots[ij] = players_info_non_zealots
        dataframes_saved_zealots[ij] = players_info_zealots
    
    return dataframes_saved_zealots,dataframes_saved_non_zealots

# %%
def subplots_probability_zealots(dataframes_saved,round_ini=0,round_end=40):
    
    modas = []
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            moda_group = []
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                if player[0]["Zealot"]:
                    moda_agente = player[1]["acción"].mode()[0] 
                    moda_group.append(moda_agente)
            #print(moda_group,ij)
            modas.append(round(np.average(moda_group)))
            
    import matplotlib
    ijaux=0
    fig,ax =plt.subplots(8,3,sharex=True,sharey=True,figsize=(10,20))
    cmap = matplotlib.colors.ListedColormap(['orange', 'blue'])
    
    k = -1
    for ij,players_info in enumerate(dataframes_saved):
            group_2 = 0
            if (ij>2) and (np.mod(ij,2) != 0):
                group_2 = 3
            for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
                players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
                k+=1
                suc = []
                sampenl = []
                av_mark = []
                std_mark = []
                av_mark_2 = []
                std_mark_2 = []
                grupo = []
                grupo_2 = []

                for j in range(len(players_info_group)):
                    lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["acción"].iloc[i]==modas[k]]
                    lista_prueba_2 = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["acción"].iloc[i]!=modas[k]]
                    lista_dic = {"amarillo":0,"azul":1}
                    #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                    #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                    av_mark.append(lista_prueba.count(1.0)/(round_end-round_ini))
                    av_mark_2.append(lista_prueba_2.count(1.0)/(round_end-round_ini))
                    grupo.append(players_info[j][0]["Marker"])
                    grupo_2.append(players_info[j][1]["success"].iloc[round_end])

                groupaux=0
                if group==4:
                    ijaux +=1
                if group>3:
                    groupaux= -3
                ax[ij+ijaux,group+groupaux-1].set_title("Group: "+str(group+group_2), fontsize=16)
                if (group+group_2)== 1 :
                        ax[ij+ijaux,group+groupaux-1].set_ylabel(es[ij],fontsize=15)
                plt.xlim((-0.1,1.1))
                plt.ylim((-0.1,1.1))
                for color in lista_dic.keys():
                    temp_x = list(filter(lambda x:grupo[x] == color,range(len(av_mark))))
                    plot_x = [av_mark[x] for x in temp_x]
                    plot_y = [av_mark_2[x] for x in temp_x]
                    ax[ij+ijaux,group+groupaux-1].scatter(plot_x,plot_y,label=color,c=cmap.colors[lista_dic[color]],cmap=cmap)
        #fig.savefig("subplots_success,"+str(round_end)+".jpg")
    return

# %%
round_ini=0
round_end=50
lista_dic = {"amarillo":0,"azul":1}
change = [0,1,2,4,6]
for ij,players_info in enumerate(dataframes_saved):
        if ij in change: 
            suc = []
            sampenl = []
            av_mark = []
            std_mark = []
            av_mark_2 = []
            std_mark_2 = []
            grupo = []
            grupo_2 = []
        for j in range(len(players_info)):
            lista_prueba = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                            if players_info[j][1]["marker_partner"].iloc[i]=='azul']
            lista_prueba_2 = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                            if players_info[j][1]["marker_partner"].iloc[i]=='amarillo']
            av_mark.append(lista_prueba.count(1.0)/len(lista_prueba))
            av_mark_2.append(lista_prueba_2.count(1.0)/len(lista_prueba_2))
            grupo.append(players_info[j][0]["Marker"])
            grupo_2.append(players_info[j][1]["success"].iloc[round_end])
            data_plot = pd.DataFrame({"coord_same_marker":av_mark,"coord_diff_marker":av_mark_2,"grupo":grupo,"grupo_2":grupo_2})
        #sns.scatterplot(x=av_mark,y=suc,hue=grupo)
        #sns.scatterplot(x=av_mark,y=suc,hue=grupo,size=grupo_2).set_title("Success,sample:"+str(len(av_mark)))
        if ij+1 in change:
            plt.figure()
            p=sns.jointplot(data= data_plot,x="coord_same_marker",y="coord_diff_marker",hue=grupo)
            p.fig.suptitle(str(es[ij]))
            plt.xlim((-0.1,1.1))
            plt.ylim((-0.1,1.1))

# %%
round_ini=0
round_end=20
distance = lambda x:np.abs(x[0]-x[1])
for ij,players_info in enumerate(dataframes_saved):
        if ij in change: 
            suc = []
            sampenl = []
            av_mark = []
            std_mark = []
            av_mark_2 = []
            std_mark_2 = []
            grupo = []
            grupo_2 = []
            b= []
            for j in range(len(players_info)):
                lista_prueba = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info[j][1]["marker_partner"].iloc[i]=='azul']
                lista_prueba_2 = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info[j][1]["marker_partner"].iloc[i]=='amarillo']
                #lista_dic = {"amarillo":0,"azul":1}
                av_mark.append(lista_prueba.count(-0.5)/len(lista_prueba))
                av_mark_2.append(lista_prueba_2.count(-0.5)/len(lista_prueba_2))
                grupo.append(players_info[j][0]["Marker"])
                grupo_2.append(len(players_info[j][2][players_info[j][2]["selectionYellow"] == 1.0]))
            #sns.scatterplot(x=av_mark,y=suc,hue=grupo)
            #sns.scatterplot(x=av_mark,y=suc,hue=grupo,size=grupo_2).set_title("Success,sample:"+str(len(av_mark)))
        if ij+1 in change:
            plt.figure()
            sns.scatterplot(x=av_mark,y=av_mark_2,hue=grupo,size=grupo_2).set_title(es[ij])
            plt.xlabel("Fracasos con azul")
            plt.ylabel("Fracasos con amarillo")
            plt.xlim((-0.1,1.1))
            plt.ylim((-0.1,1.1))
            plt.figure()
            a = list(zip(av_mark,av_mark_2))
            for item in a : 
                b.append(distance(item))
            plt.hist(b,bins=np.arange(0,1,0.1))
        #sns.scatterplot(x=av_mark_2,y=suc,hue=grupo)
        #plt.scatter(av_mark_2,suc,label="error",c=grupo)
        #plt.scatter(suc,sampenl,label = study_sessions[ij])

# %%
def histo_distance_to_line(dataframes_saved):
    round_ini=0
    round_end=40
    distance = lambda x:np.abs(x[0]-x[1])
    for ij,players_info in enumerate(dataframes_saved):
            if ij == 0 or ij==4:
                suc = []
                sampenl = []
                av_mark = []
                std_mark = []
                av_mark_2 = []
                std_mark_2 = []
                grupo = []
                grupo_2 = []
                b=[]
            for j in range(len(players_info)):
                lista_prueba = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info[j][1]["marker_partner"].iloc[i]=='azul']
                lista_prueba_2 = [players_info[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info[j][1]["marker_partner"].iloc[i]=='amarillo']
                #lista_dic = {"amarillo":0,"azul":1}
                #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                sampenl.append(ApEn(lista_prueba,2,std_prueba*0.2))
                suc.append(players_info[j][1]["success"].iloc[-1])
                av_mark.append(lista_prueba.count(1.0)/len(lista_prueba))
                av_mark_2.append(lista_prueba_2.count(1.0)/len(lista_prueba_2))
                grupo.append(players_info[j][0]["Marker"])
                grupo_2.append(players_info[j][1]["success"].iloc[round_end])
            a = list(zip(av_mark,av_mark_2))
            for item in a : 
                b.append(distance(item))
            #sns.scatterplot(x=av_mark,y=suc,hue=grupo)
            #sns.scatterplot(x=av_mark,y=suc,hue=grupo,size=grupo_2).set_title("Success,sample:"+str(len(av_mark)))
            if ij==1 or ij ==3:
                plt.hist(b,alpha=0.7,label=study_sessions[ij],bins=np.arange(0,1,0.1),density=True)
                plt.legend()
    return

# %% [markdown]
# ## Commentaries over the grouped sessions
#
#
# ### Comparing the homophily parameter with the rate of success depending on the marker of the partner. PAYOFF-MARKER_PARTNER 0
# * The first thing that we did and makes sense with the results of the paper. We created the variable (success prob with one marker, success prob with the other marker). Then, we measured for each agent, the distance to the line that defines the equal probability for both markers, only because it is symmetric. Then we make a histogram  of this distances for both e. -What we found is that the distribution for <i>e=1</i> is slightly more picuda than the one with <i>e=0.5</i>. It is symmetric, but interesting to note the difference in the organization of the points between the two <i>e</i>.

# %%
#Cálculo de la matriz A de aciertos para cada agente
for ij,players_info in enumerate(dataframes_saved):
    for ij2,player in enumerate(players_info):
        A = np.zeros((2,2))
        acción_partner = player[1]["acción_partner"]-1
        #marker_partner = [lista_dic[player[1]["marker_partner"].iloc[i]] for i in range(len(player[1]))]
        marker_partner = [0 if player[1]["marker_partner"].iloc[i] == player[0]["Marker"] else 1 for i in range(len(player[1])) ]
        for ij3 in range(len(acción_partner)):
              if np.isnan(acción_partner.iloc[ij3]) == False:
                if player[1]["payoff"].iloc[i] == 1.0:
                    #Solo matriz de éxitos
                    A[int(acción_partner.iloc[ij3]),int(marker_partner[ij3])] += 1
        #A = A/np.sum(A)
        print(A,ij,ij2)
# Out:
# [[0. 0.]
#  [0. 0.]] 0 0
# [[ 0.  6.]
#  [31. 38.]] 0 1
# [[ 2.  1.]
#  [31. 41.]] 0 2
# [[ 0.  4.]
#  [34. 37.]] 0 3
# [[ 3.  2.]
#  [32. 38.]] 0 4
# [[ 0.  4.]
#  [35. 36.]] 0 5
# [[ 0.  6.]
#  [32. 37.]] 0 6
# [[ 2.  0.]
#  [34. 39.]] 0 7
# [[0. 0.]
#  [0. 0.]] 0 8
# [[ 1.  3.]
#  [29. 42.]] 0 9
# [[ 2.  4.]
#  [33. 36.]] 0 10
# [[ 4.  0.]
#  [24. 47.]] 0 11
# [[ 0.  3.]
#  [33. 39.]] 0 12
# [[0. 0.]
#  [0. 0.]] 0 13
# [[ 1.  6.]
#  [33. 35.]] 0 14
# [[ 7.  0.]
#  [27. 41.]] 0 15
# [[ 1.  2.]
#  [38. 34.]] 0 16
# [[ 7.  3.]
#  [27. 38.]] 0 17
# [[ 3.  0.]
#  [36. 35.]] 0 18
# [[ 0.  1.]
#  [31. 43.]] 0 19
# [[ 0.  2.]
#  [34. 39.]] 0 20
# [[ 1.  0.]
#  [31. 43.]] 0 21
# [[ 0.  1.]
#  [25. 49.]] 0 22
# [[ 1.  1.]
#  [33. 40.]] 0 23
# [[ 0.  0.]
#  [28. 47.]] 0 24
# [[ 2.  2.]
#  [30. 41.]] 0 25
# [[ 0.  0.]
#  [36. 39.]] 0 26
# [[ 0.  1.]
#  [29. 45.]] 0 27
# [[ 0.  2.]
#  [31. 42.]] 0 28
# [[ 3.  0.]
#  [30. 42.]] 0 29
# [[ 1.  2.]
#  [29. 43.]] 0 30
# [[ 1.  1.]
#  [34. 39.]] 0 31
# [[ 3.  0.]
#  [28. 44.]] 0 32
# [[ 0.  2.]
#  [32. 41.]] 0 33
# [[ 1.  2.]
#  [27. 45.]] 0 34
# [[ 0.  1.]
#  [31. 43.]] 0 35
# [[0. 0.]
#  [0. 0.]] 0 36
# [[ 0.  2.]
#  [39. 34.]] 0 37
# [[0. 0.]
#  [0. 0.]] 0 38
# [[0. 0.]
#  [0. 0.]] 0 39
# [[ 9.  0.]
#  [29. 37.]] 0 40
# [[ 6.  4.]
#  [32. 33.]] 0 41
# [[ 1. 12.]
#  [30. 32.]] 0 42
# [[ 2.  8.]
#  [33. 32.]] 0 43
# [[0. 0.]
#  [0. 0.]] 0 44
# [[ 1. 15.]
#  [31. 28.]] 0 45
# [[ 5.  1.]
#  [26. 43.]] 0 46
# [[ 2. 11.]
#  [33. 29.]] 0 47
# [[ 1.  7.]
#  [38. 29.]] 0 48
# [[46. 27.]
#  [ 1.  1.]] 0 49
# [[22. 48.]
#  [ 4.  1.]] 0 50
# [[48. 20.]
#  [ 5.  2.]] 0 51
# [[0. 0.]
#  [0. 0.]] 0 52
# [[0. 0.]
#  [0. 0.]] 0 53
# [[15. 54.]
#  [ 2.  4.]] 0 54
# [[50. 20.]
#  [ 4.  1.]] 0 55
# [[54. 17.]
#  [ 3.  1.]] 0 56
# [[50. 22.]
#  [ 3.  0.]] 0 57
# [[44.  2.]
#  [10. 19.]] 1 0
# [[0. 0.]
#  [0. 0.]] 1 1
# [[ 3. 15.]
#  [47. 10.]] 1 2
# [[0. 0.]
#  [0. 0.]] 1 3
# [[0. 0.]
#  [0. 0.]] 1 4
# [[ 4.  9.]
#  [48. 14.]] 1 5
# [[ 2. 14.]
#  [48. 11.]] 1 6
# [[48.  4.]
#  [ 5. 18.]] 1 7
# [[ 3. 16.]
#  [52.  4.]] 1 8
# [[0. 0.]
#  [0. 0.]] 1 9
# [[0. 0.]
#  [0. 0.]] 1 10
# [[44. 12.]
#  [ 5. 14.]] 1 11
# [[16. 18.]
#  [38.  3.]] 1 12
# [[42. 20.]
#  [ 7.  6.]] 1 13
# [[19. 15.]
#  [35.  6.]] 1 14
# [[52. 13.]
#  [ 3.  7.]] 1 15
# [[24. 22.]
#  [26.  3.]] 1 16
# [[50. 15.]
#  [ 2.  8.]] 1 17
# [[0. 0.]
#  [0. 0.]] 1 18
# [[53. 10.]
#  [ 4.  8.]] 1 19
# [[0. 0.]
#  [0. 0.]] 1 20
# [[50. 20.]
#  [ 0.  5.]] 1 21
# [[0. 0.]
#  [0. 0.]] 1 22
# [[0. 0.]
#  [0. 0.]] 1 23
# [[53. 18.]
#  [ 2.  2.]] 1 24
# [[39. 21.]
#  [12.  3.]] 1 25
# [[0. 0.]
#  [0. 0.]] 1 26
# [[50. 17.]
#  [ 3.  5.]] 1 27
# [[49. 21.]
#  [ 1.  4.]] 1 28
# [[42. 28.]
#  [ 0.  5.]] 1 29
# [[0. 0.]
#  [0. 0.]] 1 30
# [[ 6.  4.]
#  [44. 21.]] 1 31
# [[ 7.  3.]
#  [47. 18.]] 1 32
# [[ 5.  5.]
#  [46. 19.]] 1 33
# [[ 7.  5.]
#  [40. 23.]] 1 34
# [[ 9.  8.]
#  [42. 16.]] 1 35
# [[0. 0.]
#  [0. 0.]] 1 36
# [[0. 0.]
#  [0. 0.]] 1 37
# [[0. 0.]
#  [0. 0.]] 1 38
# [[ 9.  8.]
#  [42. 16.]] 1 39
# [[0. 0.]
#  [0. 0.]] 1 40
# [[16. 16.]
#  [33. 10.]] 1 41
# [[0. 0.]
#  [0. 0.]] 1 42
# [[0. 0.]
#  [0. 0.]] 1 43
# [[0. 0.]
#  [0. 0.]] 1 44
# [[0. 0.]
#  [0. 0.]] 1 45
# [[0. 0.]
#  [0. 0.]] 1 46
# [[ 9. 20.]
#  [33. 13.]] 1 47
# [[41. 12.]
#  [ 5. 17.]] 1 48
# [[45. 10.]
#  [ 7. 13.]] 1 49
# [[ 8. 17.]
#  [39. 11.]] 1 50
# [[0. 0.]
#  [0. 0.]] 1 51
# [[ 6. 12.]
#  [43. 14.]] 1 52
# [[37.  7.]
#  [11. 20.]] 1 53
# [[ 7.  8.]
#  [48. 12.]] 1 54
# [[11.  8.]
#  [41. 15.]] 1 55
# [[41.  8.]
#  [ 8. 18.]] 1 56
# [[0. 0.]
#  [0. 0.]] 1 57
# [[41. 11.]
#  [11. 12.]] 1 58
# [[45.  5.]
#  [10. 15.]] 1 59
# [[0. 0.]
#  [0. 0.]] 2 0
# [[ 7.  2.]
#  [30. 36.]] 2 1
# [[14.  0.]
#  [18. 43.]] 2 2
# [[ 2.  2.]
#  [36. 35.]] 2 3
# [[ 2.  4.]
#  [40. 29.]] 2 4
# [[11.  2.]
#  [28. 34.]] 2 5
# [[0. 0.]
#  [0. 0.]] 2 6
# [[0. 0.]
#  [0. 0.]] 2 7
# [[0. 0.]
#  [0. 0.]] 2 8
# [[ 4.  2.]
#  [40. 29.]] 2 9
# [[ 0.  3.]
#  [32. 40.]] 2 10
# [[ 9.  0.]
#  [30. 36.]] 2 11
# [[0. 0.]
#  [0. 0.]] 2 12
# [[ 1.  6.]
#  [41. 27.]] 2 13
# [[10.  1.]
#  [38. 26.]] 2 14
# [[0. 0.]
#  [0. 0.]] 2 15
# [[ 0.  6.]
#  [32. 37.]] 2 16
# [[ 1.  0.]
#  [42. 32.]] 2 17
# [[10.  1.]
#  [32. 32.]] 2 18
# [[ 9.  1.]
#  [31. 34.]] 2 19
# [[ 4.  8.]
#  [30. 33.]] 2 20
# [[ 5.  4.]
#  [30. 36.]] 2 21
# [[ 4.  7.]
#  [34. 30.]] 2 22
# [[ 4.  4.]
#  [31. 36.]] 2 23
# [[0. 0.]
#  [0. 0.]] 2 24
# [[ 5.  2.]
#  [31. 37.]] 2 25
# [[ 2.  2.]
#  [35. 36.]] 2 26
# [[ 5. 10.]
#  [25. 35.]] 2 27
# [[ 2.  8.]
#  [29. 36.]] 2 28
# [[ 6.  5.]
#  [30. 34.]] 2 29
# [[10.  4.]
#  [35. 26.]] 2 30
# [[ 5.  5.]
#  [36. 29.]] 2 31
# [[ 4.  8.]
#  [34. 29.]] 2 32
# [[0. 0.]
#  [0. 0.]] 2 33
# [[ 5.  7.]
#  [38. 25.]] 2 34
# [[ 3.  6.]
#  [40. 26.]] 2 35
# [[ 8.  7.]
#  [23. 37.]] 2 36
# [[0. 0.]
#  [0. 0.]] 2 37
# [[ 2.  3.]
#  [36. 34.]] 2 38
# [[0. 0.]
#  [0. 0.]] 2 39
# [[ 4.  6.]
#  [28. 37.]] 2 40
# [[ 7.  2.]
#  [27. 39.]] 2 41
# [[ 5.  4.]
#  [34. 32.]] 2 42
# [[0. 0.]
#  [0. 0.]] 2 43
# [[ 3.  7.]
#  [29. 36.]] 2 44
# [[0. 0.]
#  [0. 0.]] 2 45
# [[ 8.  7.]
#  [26. 34.]] 2 46
# [[0. 0.]
#  [0. 0.]] 2 47
# [[ 6.  4.]
#  [30. 35.]] 2 48
# [[ 8.  2.]
#  [23. 42.]] 2 49
# [[0. 0.]
#  [0. 0.]] 2 50
# [[ 5.  5.]
#  [29. 36.]] 2 51
# [[0. 0.]
#  [0. 0.]] 2 52
# [[ 7. 10.]
#  [30. 28.]] 2 53
# [[0. 0.]
#  [0. 0.]] 2 54
# [[ 7.  6.]
#  [29. 33.]] 2 55
# [[ 7.  4.]
#  [33. 31.]] 2 56
# [[ 4.  3.]
#  [30. 38.]] 2 57
# [[ 4. 12.]
#  [29. 30.]] 2 58
# [[ 8.  5.]
#  [32. 30.]] 2 59
# [[ 3.  9.]
#  [36. 27.]] 3 0
# [[ 3. 11.]
#  [35. 26.]] 3 1
# [[0. 0.]
#  [0. 0.]] 3 2
# [[ 5.  4.]
#  [34. 32.]] 3 3
# [[ 1. 15.]
#  [34. 25.]] 3 4
# [[0. 0.]
#  [0. 0.]] 3 5
# [[ 2. 14.]
#  [28. 31.]] 3 6
# [[ 1. 13.]
#  [37. 24.]] 3 7
# [[0. 0.]
#  [0. 0.]] 3 8
# [[ 4. 14.]
#  [30. 27.]] 3 9
# [[ 3. 13.]
#  [29. 30.]] 3 10
# [[0. 0.]
#  [0. 0.]] 3 11
# [[0. 0.]
#  [0. 0.]] 3 12
# [[ 3. 13.]
#  [36. 23.]] 3 13
# [[ 2. 15.]
#  [34. 24.]] 3 14
# [[ 2. 12.]
#  [36. 25.]] 3 15
# [[0. 0.]
#  [0. 0.]] 3 16
# [[ 5. 12.]
#  [30. 28.]] 3 17
# [[0. 0.]
#  [0. 0.]] 3 18
# [[0. 0.]
#  [0. 0.]] 3 19
# [[0. 0.]
#  [0. 0.]] 3 20
# [[10.  5.]
#  [24. 36.]] 3 21
# [[0. 0.]
#  [0. 0.]] 3 22
# [[10.  8.]
#  [24. 33.]] 3 23
# [[0. 0.]
#  [0. 0.]] 3 24
# [[13.  9.]
#  [26. 27.]] 3 25
# [[ 8.  3.]
#  [30. 34.]] 3 26
# [[0. 0.]
#  [0. 0.]] 3 27
# [[ 9.  6.]
#  [37. 23.]] 3 28
# [[10. 10.]
#  [23. 32.]] 3 29
# [[0. 0.]
#  [0. 0.]] 3 30
# [[0. 0.]
#  [0. 0.]] 3 31
# [[0. 0.]
#  [0. 0.]] 3 32
# [[10.  8.]
#  [31. 26.]] 3 33
# [[0. 0.]
#  [0. 0.]] 3 34
# [[0. 0.]
#  [0. 0.]] 3 35
# [[10.  6.]
#  [25. 34.]] 3 36
# [[0. 0.]
#  [0. 0.]] 3 37
# [[0. 0.]
#  [0. 0.]] 3 38
# [[ 3. 16.]
#  [31. 25.]] 3 39
# [[ 5. 11.]
#  [37. 22.]] 3 40
# [[0. 0.]
#  [0. 0.]] 3 41
# [[0. 0.]
#  [0. 0.]] 3 42
# [[ 9. 14.]
#  [22. 30.]] 3 43
# [[0. 0.]
#  [0. 0.]] 3 44
# [[17.  9.]
#  [21. 28.]] 3 45
# [[23. 13.]
#  [12. 27.]] 3 46
# [[ 2. 15.]
#  [29. 29.]] 3 47
# [[0. 0.]
#  [0. 0.]] 3 48
# [[18.  7.]
#  [19. 31.]] 3 49
# [[0. 0.]
#  [0. 0.]] 3 50
# [[19. 11.]
#  [25. 20.]] 3 51
# [[0. 0.]
#  [0. 0.]] 3 52
# [[0. 0.]
#  [0. 0.]] 3 53
# [[0. 0.]
#  [0. 0.]] 3 54
# [[ 2.  9.]
#  [33. 31.]] 3 55
# [[15.  6.]
#  [17. 37.]] 3 56
# [[24.  9.]
#  [16. 26.]] 3 57
# [[ 6. 11.]
#  [37. 21.]] 3 58
# [[ 3.  3.]
#  [54. 15.]] 4 0
# [[ 3.  1.]
#  [42. 29.]] 4 1
# [[ 3.  1.]
#  [52. 19.]] 4 2
# [[ 3.  3.]
#  [52. 17.]] 4 3
# [[ 2.  2.]
#  [47. 24.]] 4 4
# [[ 0.  2.]
#  [53. 20.]] 4 5
# [[ 5.  0.]
#  [50. 20.]] 4 6
# [[ 5.  3.]
#  [52. 15.]] 4 7
# [[0. 0.]
#  [0. 0.]] 4 8
# [[ 3.  2.]
#  [52. 18.]] 4 9
# [[ 2.  0.]
#  [40. 33.]] 4 10
# [[ 5.  0.]
#  [48. 22.]] 4 11
# [[ 3.  5.]
#  [43. 24.]] 4 12
# [[ 2.  3.]
#  [52. 18.]] 4 13
# [[ 6.  1.]
#  [56. 12.]] 4 14
# [[0. 0.]
#  [0. 0.]] 4 15
# [[0. 0.]
#  [0. 0.]] 4 16
# [[0. 0.]
#  [0. 0.]] 4 17
# [[ 3.  3.]
#  [47. 22.]] 4 18
# [[ 6.  0.]
#  [43. 26.]] 4 19
# [[ 6.  1.]
#  [42. 26.]] 4 20
# [[ 3.  1.]
#  [42. 29.]] 4 21
# [[0. 0.]
#  [0. 0.]] 4 22
# [[ 3.  0.]
#  [54. 18.]] 4 23
# [[0. 0.]
#  [0. 0.]] 4 24
# [[ 3.  1.]
#  [45. 26.]] 4 25
# [[ 5.  1.]
#  [50. 19.]] 4 26
# [[ 3.  0.]
#  [54. 18.]] 4 27
# [[ 2.  2.]
#  [52. 19.]] 4 28
# [[ 1.  0.]
#  [52. 22.]] 4 29
# [[ 5.  1.]
#  [46. 23.]] 4 30
# [[0. 0.]
#  [0. 0.]] 4 31
# [[0. 0.]
#  [0. 0.]] 4 32
# [[ 2.  3.]
#  [51. 19.]] 4 33
# [[ 2.  0.]
#  [47. 26.]] 4 34
# [[ 7.  0.]
#  [55. 13.]] 4 35
# [[0. 0.]
#  [0. 0.]] 4 36
# [[0. 0.]
#  [0. 0.]] 4 37
# [[0. 0.]
#  [0. 0.]] 4 38
# [[0. 0.]
#  [0. 0.]] 4 39
# [[0. 0.]
#  [0. 0.]] 4 40
# [[0. 0.]
#  [0. 0.]] 4 41
# [[0. 0.]
#  [0. 0.]] 4 42
# [[ 0.  4.]
#  [48. 23.]] 4 43
# [[0. 0.]
#  [0. 0.]] 4 44
# [[0. 0.]
#  [0. 0.]] 4 45
# [[ 5.  2.]
#  [49. 19.]] 4 46
# [[0. 0.]
#  [0. 0.]] 4 47
# [[ 1.  1.]
#  [59. 14.]] 4 48
# [[0. 0.]
#  [0. 0.]] 4 49
# [[ 0.  4.]
#  [59. 12.]] 4 50
# [[ 5.  1.]
#  [50. 19.]] 4 51
# [[0. 0.]
#  [0. 0.]] 4 52
# [[0. 0.]
#  [0. 0.]] 4 53
# [[0. 0.]
#  [0. 0.]] 4 54
# [[ 0.  3.]
#  [53. 19.]] 4 55
# [[0. 0.]
#  [0. 0.]] 4 56
# [[ 2.  3.]
#  [46. 24.]] 4 57
# [[0. 0.]
#  [0. 0.]] 4 58
# [[ 2.  2.]
#  [46. 25.]] 4 59
# [[0. 0.]
#  [0. 0.]] 5 0
# [[0. 0.]
#  [0. 0.]] 5 1
# [[0. 0.]
#  [0. 0.]] 5 2
# [[0. 0.]
#  [0. 0.]] 5 3
# [[0. 0.]
#  [0. 0.]] 5 4
# [[0. 0.]
#  [0. 0.]] 5 5
# [[0. 0.]
#  [0. 0.]] 5 6
# [[0. 0.]
#  [0. 0.]] 5 7
# [[0. 0.]
#  [0. 0.]] 5 8
# [[0. 0.]
#  [0. 0.]] 5 9
# [[0. 0.]
#  [0. 0.]] 5 10
# [[0. 0.]
#  [0. 0.]] 5 11
# [[0. 0.]
#  [0. 0.]] 5 12
# [[0. 0.]
#  [0. 0.]] 5 13
# [[0. 0.]
#  [0. 0.]] 5 14
# [[0. 0.]
#  [0. 0.]] 5 15
# [[0. 0.]
#  [0. 0.]] 5 16
# [[0. 0.]
#  [0. 0.]] 5 17
# [[0. 0.]
#  [0. 0.]] 5 18
# [[0. 0.]
#  [0. 0.]] 5 19
# [[10.  0.]
#  [47. 18.]] 5 20
# [[0. 0.]
#  [0. 0.]] 5 21
# [[0. 0.]
#  [0. 0.]] 5 22
# [[11.  3.]
#  [45. 16.]] 5 23
# [[0. 0.]
#  [0. 0.]] 5 24
# [[0. 0.]
#  [0. 0.]] 5 25
# [[ 6.  6.]
#  [48. 15.]] 5 26
# [[ 7.  8.]
#  [42. 18.]] 5 27
# [[0. 0.]
#  [0. 0.]] 5 28
# [[10.  4.]
#  [43. 18.]] 5 29
# [[0. 0.]
#  [0. 0.]] 5 30
# [[ 6.  1.]
#  [47. 21.]] 5 31
# [[12.  5.]
#  [42. 16.]] 5 32
# [[13.  3.]
#  [47. 12.]] 5 33
# [[10.  2.]
#  [44. 19.]] 5 34
# [[0. 0.]
#  [0. 0.]] 5 35
# [[16.  1.]
#  [44. 14.]] 5 36
# [[0. 0.]
#  [0. 0.]] 5 37
# [[ 3.  4.]
#  [49. 19.]] 5 38
# [[ 1.  1.]
#  [51. 22.]] 5 39
# [[0. 0.]
#  [0. 0.]] 5 40
# [[ 0.  2.]
#  [53. 20.]] 5 41
# [[ 4.  1.]
#  [49. 21.]] 5 42
# [[0. 0.]
#  [0. 0.]] 5 43
# [[ 1.  1.]
#  [54. 19.]] 5 44
# [[0. 0.]
#  [0. 0.]] 5 45
# [[0. 0.]
#  [0. 0.]] 5 46
# [[ 2.  3.]
#  [47. 23.]] 5 47
# [[0. 0.]
#  [0. 0.]] 5 48
# [[0. 0.]
#  [0. 0.]] 5 49
# [[ 2.  2.]
#  [53. 18.]] 5 50
# [[ 0.  0.]
#  [61. 14.]] 5 51
# [[ 2.  0.]
#  [55. 18.]] 5 52
# [[0. 0.]
#  [0. 0.]] 5 53
# [[ 2.  0.]
#  [52. 21.]] 5 54
# [[ 2.  1.]
#  [54. 18.]] 5 55

# %% [markdown]
# ### Searching for zealots

# %% [markdown]
# * Search for zealots, make a dataframe of zealots and non-zealots and make the plot of probabilities of succeding.

# %%
#Obtain dataframes separated for zealots and non zealots

def obtain_zealots_dataframe(dataframes_saved,threshold):
    list_zealots = []
    dataframes_saved_non_zealots = [0]*len(dataframes_saved)
    dataframes_saved_zealots = [0]*len(dataframes_saved)
    for ij,players_info in enumerate(dataframes_saved):
        zealots = []

        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                moda_agente = player[1]["acción"].mode()[0] 
                zealot = len(player[1]["acción"][player[1]["acción"] == moda_agente])
                if zealot>threshold:
                    player[0]["Zealot"] = "Yes"
                else:
                    player[0]["Zealot"] = "No"
        players_info_non_zealots = list(filter(lambda x:x[0]["Zealot"] == "No",players_info))
        players_info_zealots = list(filter(lambda x:x[0]["Zealot"] == "Yes",players_info))
        dataframes_saved_non_zealots[ij] = players_info_non_zealots
        dataframes_saved_zealots[ij] = players_info_zealots
    
    return dataframes_saved_zealots,dataframes_saved_non_zealots

# %%
def subplots_probability_zealots(dataframes_saved,round_ini=0,round_end=40):
    
    modas = []
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            moda_group = []
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                if player[0]["Zealot"]:
                    moda_agente = player[1]["acción"].mode()[0] 
                    moda_group.append(moda_agente)
            #print(moda_group,ij)
            modas.append(round(np.average(moda_group)))
            
    import matplotlib
    ijaux=0
    fig,ax =plt.subplots(8,3,sharex=True,sharey=True,figsize=(10,20))
    cmap = matplotlib.colors.ListedColormap(['orange', 'blue'])
    
    k = -1
    for ij,players_info in enumerate(dataframes_saved):
            group_2 = 0
            if (ij>2) and (np.mod(ij,2) != 0):
                group_2 = 3
            for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
                players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
                k+=1
                suc = []
                sampenl = []
                av_mark = []
                std_mark = []
                av_mark_2 = []
                std_mark_2 = []
                grupo = []
                grupo_2 = []

                for j in range(len(players_info_group)):
                    lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["acción"].iloc[i]==modas[k]]
                    lista_prueba_2 = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["acción"].iloc[i]!=modas[k]]
                    lista_dic = {"amarillo":0,"azul":1}
                    #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                    #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                    av_mark.append(lista_prueba.count(1.0)/(round_end-round_ini))
                    av_mark_2.append(lista_prueba_2.count(1.0)/(round_end-round_ini))
                    grupo.append(players_info[j][0]["Marker"])
                    grupo_2.append(players_info[j][1]["success"].iloc[round_end])

                groupaux=0
                if group==4:
                    ijaux +=1
                if group>3:
                    groupaux= -3
                ax[ij+ijaux,group+groupaux-1].set_title("Group: "+str(group+group_2), fontsize=16)
                if (group+group_2)== 1 :
                        ax[ij+ijaux,group+groupaux-1].set_ylabel(es[ij],fontsize=15)
                plt.xlim((-0.1,1.1))
                plt.ylim((-0.1,1.1))
                for color in lista_dic.keys():
                    temp_x = list(filter(lambda x:grupo[x] == color,range(len(av_mark))))
                    plot_x = [av_mark[x] for x in temp_x]
                    plot_y = [av_mark_2[x] for x in temp_x]
                    ax[ij+ijaux,group+groupaux-1].scatter(plot_x,plot_y,label=color,c=cmap.colors[lista_dic[color]],cmap=cmap)
        #fig.savefig("subplots_success,"+str(round_end)+".jpg")
    return

# %%
obtain_zealots_dataframe(dataframes_saved,70)
subplots_probability_zealots(dataframes_saved,round_ini=0,round_end=40)
#len(dataframes_saved)

# %%
def ev_coordination_zealots(dataframes_saved):
    modas = []
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            moda_group = []
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                    moda_agente = player[1]["acción"].mode()[0] 
                    moda_group.append(moda_agente)
                    
            #print(moda_group,ij)
            modas +=[round(np.average(moda_group))]*len(players_info_group)
    ev_cordination_zealots = [0]*len(player[1])
    for ij,players_info in enumerate(dataframes_saved):
        for player in players_info:
            k1 = 0
            for ronda in range(75):
                if player[1]["acción"].iloc[ronda] == modas[k1]:
                    ev_cordination_zealots[ronda] += 1/len(modas) 
                k1 +=1

    return ev_cordination_zealots

# %%
plt.plot(ev_coordination_zealots(dataframes_saved))

# %%
dataframes_saved_zealots,dataframes_saved_non_zealots = obtain_zealots_dataframe(dataframes_saved,72)

# %% [markdown]
# ### Looking for correlation with first decision

# %% [markdown]
#  * Perhaps the criterion with respect which equilibria go is related with the first success

# %%
def subplots_probability_first_success(dataframes_saved,round_ini,round_end,title=""):
    import matplotlib
    fig,ax =plt.subplots(len(dataframes_saved),3,sharex=True,sharey=True,figsize=(12,8))
    fig.suptitle("Probability of succeding with first reinforce vs probability of the other,"+str(title))
    cmap = matplotlib.colors.ListedColormap(['orange', 'blue'])
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            suc = []
            sampenl = []
            av_mark = []
            std_mark = []
            av_mark_2 = []
            std_mark_2 = []
            grupo = []
            grupo_2 = []
            
            for j in range(len(players_info_group)):
                first_success = [players_info_group[j][1]["acción"].iloc[i] for i in range(len(players_info_group[j][1])) 
                                 if players_info[j][1]["payoff"].iloc[i] == 1.0][0]
                lista_prueba = [players_info_group[j][1]["acción"].iloc[i] for i in range(round_ini,round_end)
                                if players_info_group[j][1]["acción"].iloc[i] == first_success]
                lista_prueba_2 = [players_info_group[j][1]["acción"].iloc[i] for i in range(round_ini,round_end)
                                  if players_info_group[j][1]["acción"].iloc[i] != first_success]
                suc.append(players_info[j][1]["success"].iloc[-1])
                av_mark.append(len(lista_prueba))
                av_mark_2.append(len(lista_prueba_2))
                grupo.append(players_info[j][0]["Marker"])
                grupo_2.append(players_info[j][1]["success"].iloc[round_end])
            if group <4:
                #ax[ij,group-1] = sns.scatterplot(x=av_mark,y=av_mark_2,hue=grupo,size=grupo_2).set_title(study_sessions[ij]+','+str(group))
                ax[ij,group-1].scatter(av_mark,av_mark_2,c=list(map(lista_dic.get,grupo)),cmap=cmap)
                if group == 1 :
                    ax[ij,group-1].set_ylabel(study_sessions[ij])
                #plt.xlabel("Aciertos con azul")
                #plt.ylabel("Aciertos con amarillo")
                #plt.xlim((-0.1,1.1))
                #plt.ylim((-0.1,1.1))
            #sns.scatterplot(x=av_mark_2,y=suc,hue=grupo)
            #plt.scatter(av_mark_2,suc,label="error",c=grupo)
            #plt.scatter(suc,sampenl,label = study_sessions[ij])
    #fig.savefig("subplots_success_first,"+str(round_end)+".jpg")
    return

# %%
subplots_probability_first_success(dataframes_saved,0,74)

# %%
def subplots_probability_action(dataframes_saved,round_ini,round_end,title=""):
    import matplotlib
    fig,ax =plt.subplots(len(dataframes_saved),3,sharex=True,sharey=True,figsize=(15,10))
    fig.suptitle("Probability of succeding with yellow vs probability of succeding with both actions,"+str(title))
    cmap = matplotlib.colors.ListedColormap(['orange', 'blue'])
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            av_mark = []
            std_mark = []
            av_mark_2 = []
            std_mark_2 = []
            grupo = []
            grupo_2 = []
            for j in range(len(players_info_group)):
                lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info_group[j][1]["acción"].iloc[i]==1]
                lista_prueba_2 = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info_group[j][1]["acción"].iloc[i]==2]
                av_mark.append(lista_prueba.count(1.0)/(round_end-round_ini))
                av_mark_2.append(lista_prueba_2.count(1.0)/(round_end-round_ini))
                grupo.append(players_info[j][0]["Marker"])
                grupo_2.append(players_info[j][1]["success"].iloc[round_end])
            if group <4:
                ax[ij,group-1].scatter(av_mark,av_mark_2,c=list(map(lista_dic.get,grupo)),cmap=cmap)
                if group == 1 :
                    ax[ij,group-1].set_ylabel(study_sessions[ij])
                plt.xlim((-0.1,1.1))
                plt.ylim((-0.1,1.1))
    fig.savefig("subplots_success_action,"+str(round_end)+".jpg")
    return

# %%
subplots_probability_action(dataframes_saved_non_zealots,40,60)

# %% [markdown]
# ### Sesgo en acciones
#
# * Hay un sesgo, no sé si sucede también con N = 10, tendiente al círculo como forma predominante, independientemente del grupo. También está correlacionado con que gran parte de los zealots tienden al círculo.

# %%
for i in range(len(dataframes_saved)):
    print(len(dataframes_saved_zealots[i]),len(dataframes_saved_non_zealots[i]))
# Out:
# 37 21
# 14 46
# 15 45
# 13 46
# 26 34
# 20 36

# %%
ij
# Out:
# 5

# %%
for ij,players_info in enumerate(dataframes_saved_zealots):
    for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
        players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
        print(es[ij],group,len(players_info_group))
# Out:
# N=10;e=1 1 6
# N=10;e=1 2 7
# N=10;e=1 3 7
# N=10;e=1 4 8
# N=10;e=1 5 4
# N=10;e=1 6 5
# N=10;e=0.5 1 3
# N=10;e=0.5 2 1
# N=10;e=0.5 3 3
# N=10;e=0.5 4 4
# N=10;e=0.5 5 3
# N=10;e=0.5 6 0
# N=20;e=1 1 8
# N=20;e=1 2 2
# N=20;e=1 3 5
# N=20;e=1 1 7
# N=20;e=1 2 4
# N=20;e=1 3 2
# N=20;e=0.5 1 11
# N=20;e=0.5 2 9
# N=20;e=0.5 3 6
# N=20;e=0.5 1 4
# N=20;e=0.5 2 5
# N=20;e=0.5 3 11

# %%
for ij,players_info in enumerate(dataframes_saved):
    for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
        players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
        print(es[ij],group,len(players_info_group))
# Out:
# N=10;e=1 1 10
# N=10;e=1 2 9
# N=10;e=1 3 10
# N=10;e=1 4 10
# N=10;e=1 5 10
# N=10;e=1 6 9
# N=10;e=0.5 1 10
# N=10;e=0.5 2 10
# N=10;e=0.5 3 10
# N=10;e=0.5 4 10
# N=10;e=0.5 5 10
# N=10;e=0.5 6 10
# N=20;e=1 1 20
# N=20;e=1 2 20
# N=20;e=1 3 20
# N=20;e=1 1 20
# N=20;e=1 2 19
# N=20;e=1 3 20
# N=20;e=0.5 1 20
# N=20;e=0.5 2 20
# N=20;e=0.5 3 20
# N=20;e=0.5 1 18
# N=20;e=0.5 2 19
# N=20;e=0.5 3 19

# %%
fig,ax =plt.subplots(len(dataframes_saved),1,sharex=True,sharey=True,figsize=(10,20))
dic_bias = {'amarillo':532,'azul':594}
for ij,players_info in enumerate(dataframes_saved):
    distancias_igual = [0 for ij in range(len(players_info))]
    distancias_diff =  [0 for ij in range(len(players_info))]
    for i in range(len(players_info)):
        for mode in ['igual','diferente']:
            if mode == 'igual':
                distancias_igual[i] = abs(dic_bias[players_info[i][0]['Marker']] - players_info[i][0]['Bias'])
            else: 
                if players_info[i][0]['Marker'] == 'amarillo': maskarita = 'azul'
                if players_info[i][0]['Marker'] == 'azul': maskarita = 'amarillo'
                distancias_diff[i] = abs(dic_bias[maskarita] - players_info[i][0]['Bias'])


    nearer = [(distancias_diff[i]-distancias_igual[i])/(distancias_igual[i]+distancias_diff[i]) for i in range(len(distancias_igual))]
    bias_plots = pd.DataFrame({'distance to same marker reference':distancias_igual,
                          'distance to different marker reference':distancias_diff,
                          'trust': nearer
                          })
    print(ij)
    ax[ij].hist(bias_plots['trust'])
    ax[ij].set_ylabel(es[ij])
    if ij == 0:
        ax[ij].set_title("Trust distributions")
    if ij == len(dataframes_saved):
        ax[ij].set_xlabel("Trust")
#plt.savefig(os.path.join(start_point,join_name)+'/trust_'+str(join_name)+'.eps')
#plt.close(fig)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
def subplots_probability_norm(dataframes_saved,round_ini=0,round_end=40):
    
    modas = []
    for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            moda_group = []
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            zealots = []
            moda_zealots = []
            for ij2,player in enumerate(players_info_group):
                #Created list of zealots in our subgroup
                if player[0]["Zealot"]:
                    moda_agente = player[1]["acción"].mode()[0] 
                    moda_group.append(moda_agente)
            #print(moda_group,ij)
            modas.append(round(np.average(moda_group)))
            
    import matplotlib
    ijaux=0
    fig,ax =plt.subplots(8,3,sharex=True,sharey=True,figsize=(10,20))
    cmap = matplotlib.colors.ListedColormap(['orange', 'blue'])
    fig.suptitle("Proportion of norm_compliance (y) vs proportion of action following the zealots action (x)")
    k = -1
    for ij,players_info in enumerate(dataframes_saved):
            for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
                players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
                k+=1
                suc = []
                sampenl = []
                av_mark = []
                std_mark = []
                av_mark_2 = []
                std_mark_2 = []
                grupo = []
                grupo_2 = []

                for j in range(len(players_info_group)):
                    lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                    if players_info_group[j][1]["acción"].iloc[i]==modas[k]]
                    lista_dic = {"amarillo":0,"azul":1}
                    #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                    #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                    av_mark.append(len(lista_prueba)/(round_end-round_ini))
                    av_mark_2.append(len(players_info_group[j][2][players_info_group[j][2]["selectionYellow"] == 1.0])/20)
                    grupo.append(players_info[j][0]["Marker"])
                    

                groupaux=0
                if group==4:
                    ijaux +=1
                if group>3:
                    groupaux= -3
                ax[ij+ijaux,group+groupaux-1].scatter(av_mark,av_mark_2,c=list(map(lista_dic.get,grupo)),cmap=cmap)
                ax[ij+ijaux,group+groupaux-1].title.set_text("Group: "+str(group))
                if group == 1 :
                    ax[ij+ijaux,group+groupaux-1].set_ylabel(es[ij])
                #plt.xlabel("Aciertos con azul")
                #plt.ylabel("Aciertos con amarillo")
                #plt.xlim((-0.1,1.1))
                #plt.ylim((-0.1,1.1))
                
                
        #fig.savefig("subplots_success,"+str(round_end)+".jpg")

    return

# %%
subplots_probability_norm(dataframes_saved,0,50)

# %%
coord_rate_total = []
coord_rate_unique = []
for ij,players_info  in enumerate(dataframes_saved):
    round_ini = 0
    round_end = 40
    for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
        players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
        coord_rate = []
        for player in players_info_group:
            a = [player[1]["payoff"].iloc[i] for i in range(round_ini,round_end)].count(1.0)
            coord_rate.append(a)
            coord_rate_unique.append(a)
        coord_rate_total.append(coord_rate)
#del coord_rate_total[3]

# %%
import numpy as np
print(np.average([0.7,0.4,0.4,0.4,0.3,0.15,0.6,0.8,0.5,0.5,0.4,0.8]),np.average([0.6,0.6,1.0,0.7,0.4,0.5,0.2,0.4,0.4,0.3,0.25,0.35]))
# Out:
# 0.49583333333333335 0.47500000000000003

# %%
os.chdir(start_point)
# %run RL_marker_trax.py
# %run RL_simpler_trax.py
round_end = 40
bins = 40
##Insert loop
#learning_rate = [0.7,0.4,0.4,0.4,0.3,0.15,0.6,0.8,0.5,0.5,0.4,0.8]
#for N = 20
learning_rate = [0.6,0.6,1.0,0.7,0.4,0.5,0.2,0.4,0.4,0.3,0.25,0.35]
es = [1,1,1,1,1,1,0.5,0.5,0.5,0.5,0.5,0.5] 
fig,ax =plt.subplots(4,3,sharex=True,figsize=(10,20))
fig.suptitle("Experimental and simulated cooordination rates for N = 10")
for var_aux in range(12):
    print(var_aux)
    ax_0 = var_aux//3
    ax_1 = var_aux%3
    final_results = RL_simpler_trax(learning_rate[var_aux],es[var_aux])
    final_results_mark = RL_marker_trax(learning_rate[var_aux],es[var_aux])
    ax[ax_0,ax_1].set_ylim([0,7])
    #ax.set_xlim([0,10]
    #if ax_1 == 0:
        #ax[ax_0,ax_1].set_ylabel(study_sessions[ax_0])
    
    ax[ax_0,ax_1].hist(coord_rate_total[var_aux],range=(0,40),bins=40,label ="Experimental coordination rate")
    ax[ax_0,ax_1].plot(np.linspace(0,round_end,bins),final_results[0],label = "Simpler RL",linewidth = 4,color="r")
    ax[ax_0,ax_1].fill_between(np.linspace(0,round_end,bins), np.array(final_results[0])-2*np.array(final_results[1]), np.array(final_results[0])+2*np.array(final_results[1]),alpha=0.2,color="r")
    ax[ax_0,ax_1].plot(np.linspace(0,round_end,bins),final_results_mark[0],label = "Marked RL",linewidth = 4,color = "g")
    ax[ax_0,ax_1].fill_between(np.linspace(0,round_end,bins), np.array(final_results_mark[0])-2*np.array(final_results_mark[1]), np.array(final_results_mark[0])+2*np.array(final_results_mark[1]),alpha=0.2,color="g")
    if var_aux == 2:
        ax[ax_0,ax_1].legend(loc = "upper right")
# Out:
# 0
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_55621/2669610573.py in <module>
#      16     ax_1 = var_aux%3
#      17     final_results = RL_simpler_trax(learning_rate[var_aux],es[var_aux])
# ---> 18     final_results_mark = RL_marker_trax(learning_rate[var_aux],es[var_aux])
#      19     ax[ax_0,ax_1].set_ylim([0,7])
#      20     #ax.set_xlim([0,10]
#
# ~/Experimentos/RL_marker_trax.py in RL_marker_trax(l, e)
#      84                 else:
#      85                     couple = rd.sample(subset_total,2)
# ---> 86                 subset_total.remove(couple[0])
#      87                 subset_total.remove(couple[1])
#      88                     ##Choose field of action
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=(12,8))
plt.ylim(0,4)
av_learning = np.average(learning_rate)
final_results = RL_simpler_trax(av_learning,1)
final_results_mark = RL_marker_trax(av_learning,0.5)
coord_hist = np.histogram(coord_rate_unique,bins=40,range=(0,40))[0]
scaler = sum(final_results[0])/sum(coord_hist)
coord_hist = [coord_hist[i]*scaler for i in range(len(coord_hist))]
plt.bar(np.linspace(0,round_end,bins),coord_hist,width = 1,label = "Experimental coordination rate")
plt.plot(np.linspace(0,round_end,bins),final_results[0],label = "Simpler RL",linewidth = 4,color="r")
plt.fill_between(np.linspace(0,round_end,bins), np.array(final_results[0])-np.array(final_results[1]), np.array(final_results[0])+np.array(final_results[1]),alpha=0.2,color="r")
plt.plot(np.linspace(0,round_end,bins),final_results_mark[0],label = "Marked RL",linewidth = 4,color = "g")
plt.fill_between(np.linspace(0,round_end,bins), np.array(final_results_mark[0])-np.array(final_results_mark[1]), np.array(final_results_mark[0])+np.array(final_results_mark[1]),alpha=0.2,color="g")
plt.title("Coordination rate for N=10, e=0.5 in the marked case")
plt.legend()

# %%
fig = plt.figure(figsize=(12,8))
plt.ylim(0,4)
av_learning = np.average(learning_rate)
final_results = RL_simpler_trax(av_learning,1)
final_results_mark = RL_marker_trax(av_learning,1)
coord_hist = np.histogram(coord_rate_unique,bins=40,range=(0,40))[0]
scaler = sum(final_results[0])/sum(coord_hist)
coord_hist = [coord_hist[i]*scaler for i in range(len(coord_hist))]
plt.bar(np.linspace(0,round_end,bins),coord_hist,width = 1,label = "Experimental coordination rate")
plt.plot(np.linspace(0,round_end,bins),final_results[0],label = "Simpler RL",linewidth = 4,color="r")
plt.fill_between(np.linspace(0,round_end,bins), np.array(final_results[0])-np.array(final_results[1]), np.array(final_results[0])+np.array(final_results[1]),alpha=0.2,color="r")
plt.plot(np.linspace(0,round_end,bins),final_results_mark[0],label = "Marked RL",linewidth = 4,color = "g")
plt.fill_between(np.linspace(0,round_end,bins), np.array(final_results_mark[0])-np.array(final_results_mark[1]), np.array(final_results_mark[0])+np.array(final_results_mark[1]),alpha=0.2,color="g")
plt.title("Coordination rate for N=10, e=1 in the marked case")
plt.legend()

# %%
#limit_zealot = 70
#Zealots=[0.6,0.45,0.4,0.25,0.45,0.4,]
#l = [0.2,0.2,0.15,0.1,0.2,0.1]

dataframes_saved_zealots,dataframes_saved_non_zealots = obtain_zealots_dataframe(dataframes_saved,73)
len(dataframes_saved_zealots[0]),len(dataframes_saved_zealots[1])

# %%
last_change =[]
for j,player in enumerate(players_info_group):
    index_final = players_info_group[j][1]["change_acción"][players_info_group[j][1]["change_acción"] != 0 ]
    if len(index_final)>0:
        last_change.append(players_info_group[j][1]["round_number"][index_final.index[0]])
    else:
        last_change.append(0)

# %%
##Finding zealots 
# In order to find zealots, search for unrewarded behavior that got repeated ro
round_end = 40 
lengths_total = []
sum_lengths = []
for ij,players_info in enumerate(dataframes_saved):
    for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
        lengths_group = []
        players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
        for player in players_info_group:
            a = [player[1]["round_number"].iloc[i+1] for i in range(round_end-1) if player[1]["payoff"].iloc[i] == -0.5]#unrewarded
            b = [player[1]["round_number"].iloc[i+1] for i in range(round_end-1) if player[1]["acción"].iloc[i] == player[1]["acción"].iloc[i+1]]
            c = [value for value in a if value in b]
            lengths_group.append(len(c))
            sum_lengths.append(len(c))
        lengths_total.append(lengths_group)
##The distribution of zealots is a poissonian, we have to find a criteria for zealot related to the 
#l, the learning rate.

# %%
scaler = len(prob_err_global)/np.average([len(lengths_total[i]) for i in range(len(lengths_total))])
for i in range(len(lengths_total)):
    plt.hist(lengths_total[i],alpha=0.7,range=(0,40),bins=40)
plt.plot([prob_err_global[i]*scaler for i in range(len(prob_err_global))],linewidth = 4)
plt.plot([prob_err_global_mark[i]*scaler for i in range(len(prob_err_global))],linewidth = 4)

# %%
round_ini = 35
round_end = 40
times = [] 
for ij,players_info in enumerate(dataframes_saved):
    for ij2,player in enumerate(players_info):
        player_40 = player[1]["acción"][round_ini:round_end]
        freq_action = player_40.mode()[0]
        times.append(player_40.value_counts()[freq_action])

# %%
plt.figure(figsize=(12,8))
ax = plt.gca()
ax.set_xlim([0.5,1.01])
ax.set_ylim([-0.1,20])
scaler2 = sum(prob_dist_global)/sum(hist_times[0])
hist_times = np.histogram(times,bins=40,range=(0,round_end-round_ini))
hist_scaled = [hist_times[0][i]*scaler2 for i in range(len(hist_times[0]))]
plt.scatter(np.linspace(0,1,40),hist_scaled,linewidth=4)
plt.plot(np.linspace(0,1,40),prob_dist_global,linewidth=4,c="r")
#plt.fill_between(np.linspace(0,round_end,bins), np.array(prob_dist_new)-2*np.array(prob_dist_2_new), np.array(prob_dist_new)+2*np.array(prob_dist_2_new),alpha=0.2,color="r")
#plt.fill_between(np.linspace(0,round_end,bins), np.array(prob_dist_new)-2*np.array(prob_dist_2_new), np.array(prob_dist_new)-2*np.array(prob_dist_2_new),alpha=0.2,color="r")

# %%
freq = []
round_end = 40
for ij,players_info in enumerate(dataframes_saved):
            for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
                players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
                a = [players_info_group[i][1]["acción"].iloc[round_end-1] for i in range(len(players_info_group))]
                freq.append(max(a.count(1),a.count(2))/len(a))

# %%
for var_aux in range(len(coord_rate_total)):

    print(var_aux,ax_0,ax_1)

# %%
sum(coord_rate_total[4]),sum(final_results[0])

# %%
plt.scatter(np.linspace(0,1,40),np.histogram(coord_rate_total[4],bins=40,range=(0,40))[0])

# %%
np.average(learning_rate)

# %%
start_point

# %%
import math
dist_player_2_ev = []
dist_player_1_ev = []
dist_val = []
for ij,players_info in enumerate(dataframes_saved):
    for ij2,player in enumerate(players_info):
        dist_player_2 = []
        dist_player_1 = []
        dist_player_2 = [player[1]["pay_2_val"].iloc[i] for i in range(len(player[1])) if math.isnan(player[1]["pay_2_val"].iloc[i]) == False]
        dist_player_1 = [player[1]["pay_1_val"].iloc[i] for i in range(len(player[1])) if math.isnan(player[1]["pay_1_val"].iloc[i]) == False]
        #dist_val +=[dist_player_2[i]-dist_player_1[i] for i in range(len(dist_player_2))]
        dist_player_2_ev.append(np.average([dist_player_2[i]-dist_player_2[i-1] for i in range(1,len(dist_player_2))]))
        dist_player_1_ev.append(np.average([dist_player_1[i]-dist_player_1[i-1] for i in range(1,len(dist_player_1))]))

# %%
fig = plt.figure(figsize=(12,8))
plt.title("Evolution of the Likert scale choice",fontsize=15)
plt.hist(dist_player_1_ev,label = "Uncoordination",alpha = 0.7)
plt.hist(dist_player_2_ev,label = "Coordination",alpha = 0.7)
plt.legend()

# %%
fig = plt.figure(figsize=(12,8))
plt.title("Distribution of the differences in the aspirations ",fontsize=15)

plt.hist(dist_val)

# %%
len([dist_val[i] for i in range(len(dist_val)) if dist_val[i]>0])/len(dist_val)

# %%
ene = []
average_x = []
average_y = []
var = []
es = [1,0.5,1,1,0.5,0.5]
for ij,players_info in enumerate(dataframes_saved):
        for group in range(1,int(dataframes_saved[ij][-1][0]['id_in_subsession']+1)):
            players_info_group = [players_info[i] for i in range(len(players_info)) if players_info[i][0]['id_in_subsession'] == group]
            suc = []
            sampenl = []
            av_mark = []
            std_mark = []
            av_mark_2 = []
            std_mark_2 = []
            grupo = []
            grupo_2 = []

            for j in range(len(players_info_group)):
                lista_prueba = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info_group[j][1]["marker_partner"].iloc[i]==players_info_group[j][0]["Marker"]]
                lista_prueba_2 = [players_info_group[j][1]["payoff"].iloc[i] for i in range(round_ini,round_end)
                                if players_info_group[j][1]["marker_partner"].iloc[i]!=players_info_group[j][0]["Marker"]]
                lista_dic = {"amarillo":0,"azul":1}
                #lista_prueba = [lista_dic[lista_prueba[i]] for i in range(len(lista_prueba))]
                #lista_prueba_2 = [lista_dic[lista_prueba_2[i]] for i in range(len(lista_prueba_2))]
                suc.append(players_info[j][1]["success"].iloc[-1])
                av_mark.append(lista_prueba.count(1.0)/len(lista_prueba))
                av_mark_2.append(lista_prueba_2.count(1.0)/len(lista_prueba_2))
                grupo.append(players_info[j][0]["Marker"])
                grupo_2.append(players_info[j][1]["success"].iloc[round_end])
            average_x.append(np.average(av_mark))
            average_y.append(np.average(av_mark_2))
            var.append(max(np.var(av_mark),np.std(av_mark_2)))
            ene.append(round((len(players_info_group)*(es[ij]*4-3))/10)*10)

# %%
data_hyp2

# %%
data_hyp2 = pd.DataFrame({"Coord with same marker":average_x,"Coord with diff marker":average_y,"Configuration":ene,"Std":var})
sns.set_context("notebook")
#plt.title("Group size vs homophily vs average coordination",fontsize=15)
ax = sns.displot(data_hyp2,x="Coord with same marker",y="Coord with diff marker",hue = "Configuration",palette="Set1", height=6, aspect=1.5)
ax.fig.suptitle("Coord vs e vs group size")

# %%
sns.relplot(data=data_hyp2,x="Coord with same marker",y="Coord with diff marker",hue = "Configuration",size = "Std",sizes=(15, 200),palette="Set1", height=6, aspect=1.5)
