# %% [markdown]
# ## Data visualization with pandas

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
#%run python1.py

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Style Sheets
#
# **Before plt.style.use() your plots look like this:**

# %%
df1[['A','B']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'B'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
plt.style.use('ggplot')
df2.plot.area(alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.reset_index(inplace=True)
df1.plot.line(x="index",y='B')
# Out:
# <AxesSubplot:xlabel='index'>

# %%
df
# Out:
#             a         b
# 0   -0.113129  1.436789
# 1   -0.136281  1.365663
# 2   -0.247297  1.009496
# 3   -0.060236  0.634162
# 4   -1.469881  2.009156
# ..        ...       ...
# 995  1.252103  1.417470
# 996 -1.145083  1.979318
# 997 -0.281504 -0.599966
# 998 -0.397008 -0.463048
# 999 -1.241060  1.341286
#
# [1000 rows x 2 columns]

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1
# Out:
#           index         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# /home/juan/.local/lib/python3.8/site-packages/matplotlib/collections.py:981: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# **Exercises**

# %% [markdown]
# With the salaries.csv file used previously, compute :
#
#  * The histogram of the BasePay
#  * The scatterplot of the BasePay and the overtimePay, such that the size of the dots represent the OtherPay,
#      in a proper scale.
#  * A bar plot of the different numerical quantities for the first five employees.
#
#  * An area plot of BaseTimePay and TotalPay such that total stays on the top of BasePay

# %%
print(u"\u2b1c")
# Out:
# ⬜
