# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# fatal: destination path 'rl-baselines3-zoo' already exists and is not an empty directory.

# %%
# %cd rl-baselines3-zoo/
# Out:
# /home/juan/Python/Python_courses/RL/rl-baselines3-zoo

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/huggingface/huggingface_sb3 (from -r requirements.txt (line 19))
#   Cloning https://github.com/huggingface/huggingface_sb3 to /tmp/pip-req-build-d3cqs0te
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/huggingface_sb3 /tmp/pip-req-build-d3cqs0te
#   Resolved https://github.com/huggingface/huggingface_sb3 to commit 19880b8b82a100f24c1eeb6ba377cc0c2f5e8c1f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym==0.21 in /home/juan/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (0.21.0)
# Collecting stable-baselines3[docs,extra,tests]>=1.5.1a7
#   Using cached stable_baselines3-1.5.1a7-py3-none-any.whl (177 kB)
# Collecting sb3-contrib>=1.5.1a8
#   Using cached sb3_contrib-1.5.1a8-py3-none-any.whl (78 kB)
# Collecting box2d-py==2.3.8
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pybullet in /home/juan/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (3.2.5)
# Collecting gym-minigrid
#   Using cached gym_minigrid-1.0.3-py3-none-any.whl (48 kB)
# Collecting scikit-optimize
#   Using cached scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Collecting optuna
#   Using cached optuna-2.10.0-py3-none-any.whl (308 kB)
# Collecting pytablewriter~=0.64
#   Using cached pytablewriter-0.64.2-py3-none-any.whl (106 kB)
# Requirement already satisfied: seaborn in /home/juan/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.11.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/juan/.local/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (6.0)
# Collecting cloudpickle>=1.5.0
#   Using cached cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: plotly in /home/juan/.local/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (5.7.0)
# Collecting panda-gym==1.1.1
#   Using cached panda_gym-1.1.1-py3-none-any.whl (21 kB)
# Collecting rliable>=1.0.5
#   Using cached rliable-1.0.7-py3-none-any.whl (19 kB)
# Collecting wandb
#   Using cached wandb-0.12.18-py2.py3-none-any.whl (1.8 MB)
# Collecting ale-py==0.7.4
#   Using cached ale_py-0.7.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# Requirement already satisfied: numpy>=1.18.0 in /home/juan/.local/lib/python3.8/site-packages (from gym==0.21->-r requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /home/juan/.local/lib/python3.8/site-packages (from ale-py==0.7.4->-r requirements.txt (line 17)) (4.11.3)
# Requirement already satisfied: importlib-resources in /home/juan/.local/lib/python3.8/site-packages (from ale-py==0.7.4->-r requirements.txt (line 17)) (5.7.1)
# Requirement already satisfied: pandas in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.4.2)
# Collecting torch>=1.11
#   Using cached torch-1.11.0-cp38-cp38-manylinux1_x86_64.whl (750.6 MB)
# Requirement already satisfied: matplotlib in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (3.5.2)
# Collecting sphinx
#   Using cached Sphinx-5.0.1-py3-none-any.whl (3.1 MB)
# Collecting sphinx-autobuild
#   Using cached sphinx_autobuild-2021.3.14-py3-none-any.whl (9.9 kB)
# Collecting sphinx-rtd-theme
#   Using cached sphinx_rtd_theme-1.0.0-py2.py3-none-any.whl (2.8 MB)
# Collecting sphinx-autodoc-typehints
#   Using cached sphinx_autodoc_typehints-1.18.3-py3-none-any.whl (12 kB)
# Collecting sphinxcontrib.spelling
#   Using cached sphinxcontrib_spelling-7.5.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: psutil in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: opencv-python in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (4.5.5.64)
# Requirement already satisfied: pillow in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (9.1.0)
# Collecting protobuf~=3.19.0
#   Using cached protobuf-3.19.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Collecting pytest
#   Using cached pytest-7.1.2-py3-none-any.whl (297 kB)
# Collecting pytest-env
#   Using cached pytest_env-0.6.2-py3-none-any.whl
# Collecting pytype
#   Using cached pytype-2022.6.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting pytest-xdist
#   Using cached pytest_xdist-2.5.0-py3-none-any.whl (41 kB)
# Collecting pytest-cov
#   Using cached pytest_cov-3.0.0-py3-none-any.whl (20 kB)
# Collecting flake8-bugbear
#   Using cached flake8_bugbear-22.4.25-py3-none-any.whl (19 kB)
# Collecting black
#   Using cached black-22.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Requirement already satisfied: isort>=5.0 in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (5.10.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/juan/.local/lib/python3.8/site-packages (from stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.8.0)
# Collecting flake8>=3.8
#   Using cached flake8-4.0.1-py2.py3-none-any.whl (64 kB)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/juan/.local/lib/python3.8/site-packages (from scikit-optimize->-r requirements.txt (line 7)) (1.0.2)
# Collecting pyaml>=16.9
#   Using cached pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: joblib>=0.11 in /home/juan/.local/lib/python3.8/site-packages (from scikit-optimize->-r requirements.txt (line 7)) (1.1.0)
# Collecting cmaes>=0.8.2
#   Using cached cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /home/juan/.local/lib/python3.8/site-packages (from optuna->-r requirements.txt (line 8)) (4.64.0)
# Collecting cliff
#   Using cached cliff-3.10.1-py3-none-any.whl (81 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /home/juan/.local/lib/python3.8/site-packages (from optuna->-r requirements.txt (line 8)) (1.4.36)
# Collecting colorlog
#   Using cached colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting alembic
#   Using cached alembic-1.8.0-py3-none-any.whl (209 kB)
# Requirement already satisfied: packaging>=20.0 in /home/juan/.local/lib/python3.8/site-packages (from optuna->-r requirements.txt (line 8)) (21.3)
# Collecting tabledata<2,>=1.3.0
#   Using cached tabledata-1.3.0-py3-none-any.whl (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0
#   Using cached mbstrdecoder-1.1.0-py3-none-any.whl (7.8 kB)
# Collecting typepy[datetime]<2,>=1.2.0
#   Using cached typepy-1.3.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /home/juan/.local/lib/python3.8/site-packages (from pytablewriter~=0.64->-r requirements.txt (line 9)) (62.2.0)
# Collecting DataProperty<2,>=0.55.0
#   Using cached DataProperty-0.55.0-py3-none-any.whl (26 kB)
# Collecting pathvalidate<3,>=2.3.0
#   Using cached pathvalidate-2.5.0-py3-none-any.whl (19 kB)
# Collecting tcolorpy<1,>=0.0.5
#   Using cached tcolorpy-0.1.2-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: tenacity>=6.2.0 in /home/juan/.local/lib/python3.8/site-packages (from plotly->-r requirements.txt (line 13)) (8.0.1)
# Requirement already satisfied: six in /home/juan/.local/lib/python3.8/site-packages (from plotly->-r requirements.txt (line 13)) (1.16.0)
# Collecting arch==5.0.1
#   Using cached arch-5.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (902 kB)
# Requirement already satisfied: absl-py>=0.9.0 in /home/juan/.local/lib/python3.8/site-packages (from rliable>=1.0.5->-r requirements.txt (line 15)) (1.0.0)
# Collecting property-cached>=1.6.4
#   Using cached property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: statsmodels>=0.11 in /home/juan/.local/lib/python3.8/site-packages (from arch==5.0.1->rliable>=1.0.5->-r requirements.txt (line 15)) (0.13.2)
# Requirement already satisfied: GitPython>=1.0.0 in /home/juan/.local/lib/python3.8/site-packages (from wandb->-r requirements.txt (line 16)) (3.1.27)
# Collecting sentry-sdk>=1.0.0
#   Using cached sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home/juan/.local/lib/python3.8/site-packages (from wandb->-r requirements.txt (line 16)) (8.1.3)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting setproctitle
#   Using cached setproctitle-1.2.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting promise<3,>=2.0
#   Using cached promise-2.3-py3-none-any.whl
# Requirement already satisfied: requests<3,>=2.0.0 in /home/juan/.local/lib/python3.8/site-packages (from wandb->-r requirements.txt (line 16)) (2.27.1)
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: pathtools in /home/juan/.local/lib/python3.8/site-packages (from wandb->-r requirements.txt (line 16)) (0.1.2)
# Collecting huggingface_hub
#   Using cached huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
# Collecting cloudpickle>=1.5.0
#   Using cached cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: wasabi in /home/juan/.local/lib/python3.8/site-packages (from huggingface-sb3==2.1.0->-r requirements.txt (line 19)) (0.9.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/juan/.local/lib/python3.8/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.2)
# Collecting pycodestyle<2.9.0,>=2.8.0
#   Using cached pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
# Collecting pyflakes<2.5.0,>=2.4.0
#   Using cached pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/juan/.local/lib/python3.8/site-packages (from flake8>=3.8->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/juan/.local/lib/python3.8/site-packages (from GitPython>=1.0.0->wandb->-r requirements.txt (line 16)) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/juan/.local/lib/python3.8/site-packages (from importlib-metadata>=4.10.0->ale-py==0.7.4->-r requirements.txt (line 17)) (3.8.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/juan/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (4.33.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/juan/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (3.0.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/juan/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/juan/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/juan/.local/lib/python3.8/site-packages (from matplotlib->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: chardet<5,>=3.0.4 in /home/juan/.local/lib/python3.8/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: pytz>=2020.1 in /home/juan/.local/lib/python3.8/site-packages (from pandas->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/juan/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 16)) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/juan/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 16)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/juan/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 16)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/juan/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb->-r requirements.txt (line 16)) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/juan/.local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->scikit-optimize->-r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/juan/.local/lib/python3.8/site-packages (from sqlalchemy>=1.1.0->optuna->-r requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: grpcio>=1.24.3 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.44.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/juan/.local/lib/python3.8/site-packages (from tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.6.6)
# Requirement already satisfied: typing-extensions in /home/juan/.local/lib/python3.8/site-packages (from torch>=1.11->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: Mako in /home/juan/.local/lib/python3.8/site-packages (from alembic->optuna->-r requirements.txt (line 8)) (1.2.0)
# Collecting pathspec>=0.9.0
#   Using cached pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: platformdirs>=2 in /home/juan/.local/lib/python3.8/site-packages (from black->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.5.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/juan/.local/lib/python3.8/site-packages (from black->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: tomli>=1.1.0 in /home/juan/.local/lib/python3.8/site-packages (from black->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.0.1)
# Collecting PrettyTable>=0.7.2
#   Using cached prettytable-3.3.0-py3-none-any.whl (26 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.9.0-py2.py3-none-any.whl (112 kB)
# Collecting cmd2>=1.0.0
#   Using cached cmd2-2.4.1-py3-none-any.whl (146 kB)
# Collecting stevedore>=2.0.1
#   Using cached stevedore-3.5.0-py3-none-any.whl (49 kB)
# Collecting autopage>=0.4.0
#   Using cached autopage-0.5.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/juan/.local/lib/python3.8/site-packages (from flake8-bugbear->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (21.4.0)
# Collecting filelock
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: iniconfig in /home/juan/.local/lib/python3.8/site-packages (from pytest->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.1.1)
# Collecting pluggy<2.0,>=0.12
#   Using cached pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting py>=1.8.2
#   Using cached py-1.11.0-py2.py3-none-any.whl (98 kB)
# Collecting coverage[toml]>=5.2.1
#   Using cached coverage-6.4.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Collecting execnet>=1.1
#   Using cached execnet-1.9.0-py2.py3-none-any.whl (39 kB)
# Collecting pytest-forked
#   Using cached pytest_forked-1.4.0-py3-none-any.whl (4.9 kB)
# Requirement already satisfied: tabulate in /home/juan/.local/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.8.9)
# Collecting libcst
#   Using cached libcst-0.4.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
# Requirement already satisfied: toml in /home/juan/.local/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: ninja>=1.10.0.post2 in /home/juan/.local/lib/python3.8/site-packages (from pytype->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.10.2.3)
# Collecting importlab>=0.7
#   Using cached importlab-0.7-py2.py3-none-any.whl
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting sphinxcontrib-applehelp
#   Using cached sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: snowballstemmer>=1.1 in /home/juan/.local/lib/python3.8/site-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.2.0)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Using cached sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
# Collecting sphinxcontrib-jsmath
#   Using cached sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting alabaster<0.8,>=0.7
#   Using cached alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-qthelp
#   Using cached sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
# Requirement already satisfied: Pygments>=2.0 in /home/juan/.local/lib/python3.8/site-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.12.0)
# Collecting docutils<0.19,>=0.14
#   Using cached docutils-0.18.1-py2.py3-none-any.whl (570 kB)
# Collecting imagesize
#   Using cached imagesize-1.3.0-py2.py3-none-any.whl (5.2 kB)
# Collecting sphinxcontrib-devhelp
#   Using cached sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
# Requirement already satisfied: babel>=1.3 in /home/juan/.local/lib/python3.8/site-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.10.1)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Using cached sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: Jinja2>=2.3 in /home/juan/.local/lib/python3.8/site-packages (from sphinx->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (3.1.2)
# Collecting livereload
#   Using cached livereload-2.6.3-py2.py3-none-any.whl
# Requirement already satisfied: colorama in /home/juan/.local/lib/python3.8/site-packages (from sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.4)
# Collecting docutils<0.19,>=0.14
#   Using cached docutils-0.17.1-py2.py3-none-any.whl (575 kB)
# Collecting PyEnchant>=3.1.1
#   Using cached pyenchant-3.2.2-py3-none-any.whl (55 kB)
# Requirement already satisfied: pyperclip>=1.6 in /home/juan/.local/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: wcwidth>=0.1.7 in /home/juan/.local/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/juan/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/juan/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/juan/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/juan/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/juan/.local/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: networkx>=2 in /home/juan/.local/lib/python3.8/site-packages (from importlab>=0.7->pytype->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/juan/.local/lib/python3.8/site-packages (from Jinja2>=2.3->sphinx->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: patsy>=0.5.2 in /home/juan/.local/lib/python3.8/site-packages (from statsmodels>=0.11->arch==5.0.1->rliable>=1.0.5->-r requirements.txt (line 15)) (0.5.2)
# Collecting typing-inspect>=0.4.0
#   Using cached typing_inspect-0.7.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: tornado in /home/juan/.local/lib/python3.8/site-packages (from livereload->sphinx-autobuild->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/juan/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/juan/.local/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[docs,extra,tests]>=1.5.1a7->-r requirements.txt (line 2)) (3.2.0)
# Building wheels for collected packages: box2d-py, huggingface-sb3
#   Building wheel for box2d-py (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [16 lines of output]
#       Using setuptools (version 62.2.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-38
#       creating build/lib.linux-x86_64-cpython-38/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-cpython-38/Box2D
#       copying library/Box2D/__init__.py -> build/lib.linux-x86_64-cpython-38/Box2D
#       creating build/lib.linux-x86_64-cpython-38/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.linux-x86_64-cpython-38/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
#   Building wheel for huggingface-sb3 (setup.py) ... done
#   Created wheel for huggingface-sb3: filename=huggingface_sb3-2.1.0-py3-none-any.whl size=7981 sha256=fd2e53a1bb76570c9de8121da1f9464019a96aac7088d63d06ce9b3a986ae658
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d3oyj3ck/wheels/69/c1/3e/888c6a623f2a20c00a7dacf6d45fce4496ecda97612b1b9fe9
# Successfully built huggingface-sb3
# Failed to build box2d-py
# Installing collected packages: box2d-py, alabaster, typing-inspect, torch, tcolorpy, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, shortuuid, setproctitle, sentry-sdk, pyflakes, PyEnchant, pydot, pycodestyle, pyaml, py, protobuf, property-cached, promise, PrettyTable, pluggy, pbr, pathvalidate, pathspec, mbstrdecoder, livereload, importlab, imagesize, filelock, execnet, docutils, docker-pycreds, coverage, colorlog, cmd2, cmaes, cloudpickle, autopage, typepy, stevedore, sphinx, pytest, libcst, huggingface_hub, flake8, black, alembic, ale-py, wandb, stable-baselines3, sphinxcontrib.spelling, sphinx-rtd-theme, sphinx-autodoc-typehints, sphinx-autobuild, scikit-optimize, pytype, pytest-forked, pytest-env, pytest-cov, panda-gym, huggingface-sb3, gym-minigrid, flake8-bugbear, cliff, sb3-contrib, pytest-xdist, optuna, DataProperty, arch, tabledata, rliable, pytablewriter
#   Running setup.py install for box2d-py ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for box2d-py did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Using setuptools (version 62.2.0).
#       running install
#       /home/juan/.local/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-38
#       creating build/lib.linux-x86_64-cpython-38/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-cpython-38/Box2D
#       copying library/Box2D/__init__.py -> build/lib.linux-x86_64-cpython-38/Box2D
#       creating build/lib.linux-x86_64-cpython-38/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.linux-x86_64-cpython-38/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> box2d-py
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: There was an error checking the latest version of pip.

# %%
# !python3 train.py --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/
# Out:
# Traceback (most recent call last):
#   File "train.py", line 15, in <module>
#     import utils.import_envs  # noqa: F401 pytype: disable=import-error
#   File "/home/juan/Python/Python_courses/RL/rl-baselines3-zoo/utils/__init__.py", line 1, in <module>
#     from .utils import (
#   File "/home/juan/Python/Python_courses/RL/rl-baselines3-zoo/utils/utils.py", line 13, in <module>
#     from sb3_contrib import ARS, QRDQN, TQC, TRPO, RecurrentPPO
# ImportError: cannot import name 'RecurrentPPO' from 'sb3_contrib' (/home/juan/.local/lib/python3.8/site-packages/sb3_contrib/__init__.py)

# %%
import sb3_contrib
