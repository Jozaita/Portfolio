# %%
# %cd rl-baselines3-zoo
# Out:
# /home/juan/Python/Python_courses/RL/rl-baselines3-zoo

# %%
# !python3 train.py --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/
# Out:
# 2022-06-11 20:10:41.664893: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/juan/.local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-06-11 20:10:41.664930: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 2050698647
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
# ...

# %%
_ih[1]
# Out:
# "get_ipython().run_line_magic('cd', 'rl-baselines3-zoo')"
