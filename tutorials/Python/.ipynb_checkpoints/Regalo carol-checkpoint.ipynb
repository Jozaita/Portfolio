# %%
from PIL import Image
import numpy as np 
import matplotlib.pyplot as plt

# %%
im = Image.open("regalo_carol.jpeg")

# %%
a = np.array(im)
black_white_image = np.array(im)[:,:,0]/256

# %%
plt.imshow(black_white_image)

# %%
plt.imshow(np.around(black_white_image))

# %%
import os
